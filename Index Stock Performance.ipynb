# %% [markdown]
# # Analyze Index Stock Performance
# SPX, QQQ, DOW

# %%
# !pip install requests pandas yfinance investpy lxml beautifulsoup4 polygon-api-client investpy tabulate openpyxl

# !pip install gspread gspread-dataframe oauth2client
# Out:
# Requirement already satisfied: requests in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: pandas in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: yfinance in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (0.2.40)
# Requirement already satisfied: investpy in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (1.0.8)
# Requirement already satisfied: lxml in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (5.2.2)
# Requirement already satisfied: beautifulsoup4 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (4.12.3)
# Requirement already satisfied: polygon-api-client in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (1.14.1)
# Requirement already satisfied: tabulate in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (0.9.0)
# Requirement already satisfied: openpyxl in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from requests) (2024.6.2)
# Requirement already satisfied: numpy>=1.26.0 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from pandas) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from yfinance) (3.17.5)
# Requirement already satisfied: html5lib>=1.1 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from yfinance) (1.1)
# Requirement already satisfied: Unidecode>=1.1.1 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from investpy) (1.3.8)
# Requirement already satisfied: setuptools>=41.2.0 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from investpy) (70.1.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: websockets<13.0,>=10.3 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from polygon-api-client) (12.0)
# Requirement already satisfied: et-xmlfile in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.9 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: gspread in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (6.1.2)
# Requirement already satisfied: gspread-dataframe in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (4.0.0)
# Requirement already satisfied: oauth2client in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (4.1.3)
# Requirement already satisfied: google-auth>=1.12.0 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from gspread) (2.31.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from gspread) (1.2.0)
# Requirement already satisfied: pandas>=0.24.0 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from gspread-dataframe) (2.2.2)
# Requirement already satisfied: six>=1.12.0 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from gspread-dataframe) (1.16.0)
# Requirement already satisfied: httplib2>=0.9.1 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from oauth2client) (0.22.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from oauth2client) (0.6.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from oauth2client) (0.4.0)
# Requirement already satisfied: rsa>=3.1.4 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from oauth2client) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from google-auth>=1.12.0->gspread) (5.3.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from httplib2>=0.9.1->oauth2client) (3.1.2)
# Requirement already satisfied: numpy>=1.26.0 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from pandas>=0.24.0->gspread-dataframe) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from pandas>=0.24.0->gspread-dataframe) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from pandas>=0.24.0->gspread-dataframe) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from pandas>=0.24.0->gspread-dataframe) (2024.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sliu/miniconda3/envs/ml4t/lib/python3.12/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.6.2)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta
from concurrent.futures import ThreadPoolExecutor

# %% [markdown]
# ## Fetch and save index components

# %%
# Fetch index components 
def fetch_components_slickcharts(index):
    base_url = "https://slickcharts.com/"
    index_map = {
        'QQQ': 'nasdaq100',
        'SPX': 'sp500',
        'DOW': 'dowjones',
        'IWM': 'russell2000'
    }
    if index.upper() not in index_map:
        raise ValueError("Index must be either 'QQQ', 'SPX', 'DOW', or 'IWM'")
    
    url = f"{base_url}{index_map[index.upper()]}"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    table = soup.find('table', {'class': 'table'})
    
    data = []
    headers = []

    for i, row in enumerate(table.find_all('tr')):
        cols = [ele.text.strip() for ele in row.find_all('td')]
        if i == 0:
            headers = [ele.text.strip() for ele in row.find_all('th')]
        else:
            if len(cols) > 1:  # Ensure there is data in the row
                data.append(cols)
    
    df = pd.DataFrame(data, columns=headers)
    return df

# %%
# Append components with industry info
from collections import Counter
import yfinance as yf
from concurrent.futures import ThreadPoolExecutor, as_completed
import pandas as pd

def fetch_industry_info(symbol):
    try:
        stock = yf.Ticker(symbol)
        info = stock.info
        industry = info.get("industry", "N/A")
        #print(f"Fetched industry for {symbol}: {industry}")
        return industry
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")
        return "N/A"

def append_industry_info(df):
    industries = []
    for _, row in df.iterrows():
        symbol = row['Symbol']
        industry = fetch_industry_info(symbol)
        industries.append(industry)
    
    df['Industry'] = industries
    return df

def print_all_company_details_compact(df, rank_by='weight'):
    # Print DataFrame columns for debugging
    print("DataFrame columns:", df.columns)
    
    # Convert 'Weight' or 'Portfolio %' column to numeric if it exists
    weight_column = 'Weight' if 'Weight' in df.columns else 'Portfolio%' if 'Portfolio%' in df.columns else None
    
    if rank_by == 'weight' and weight_column:
        df[weight_column] = df[weight_column].astype(str).str.replace('%', '').astype(float)
        df = df.sort_values(by=weight_column, ascending=False)
    elif rank_by == 'industry' and 'Industry' in df.columns:
        df = df.sort_values(by='Industry')
    
    # Get the maximum length of each column for formatting
    col_widths = [max(df[col].astype(str).map(len).max(), len(col)) for col in df.columns]
    format_str = ' | '.join([f'{{:<{width}}}' for width in col_widths])
    
    print(format_str.format(*df.columns))
    print('-' * (sum(col_widths) + 3 * (len(col_widths) - 1)))
    
    for index, row in df.iterrows():
        print(format_str.format(*row))

# %% [markdown]
# from tabulate import tabulate
#
# def display_industry_stats(df):
#     industry_stats = df['Industry'].value_counts().reset_index()
#     industry_stats.columns = ['Industry', 'Number of Companies']
#     industry_stats = industry_stats.sort_values(by='Industry')
#
#     data = []
#     for industry in industry_stats['Industry']:
#         tickers = df[df['Industry'] == industry]['Symbol'].tolist()
#         ticker_string = ", ".join(tickers)
#         data.append([industry, len(tickers), ticker_string])
#
#     print(tabulate(data, headers=["Industry", "Number of Companies", "Tickers"], tablefmt="grid", stralign="left"))

# %%
df_qqq=append_industry_info(fetch_components_slickcharts('qqq'))
df_spx=append_industry_info(fetch_components_slickcharts('spx'))
# df_qqq=append_industry_info(fetch_components_slickcharts('qqq'))

# %%
def save_dataframe_to_csv(df, filename):
    df.to_csv(filename, index=False)
    print(f"Data saved to {filename}")

def save_dataframe_to_excel(df, filename):
    df.to_excel(filename, index=False)
    print(f"Data saved to {filename}")

# Save the dataframes to files
save_dataframe_to_excel(df_qqq, 'df_qqq.xlsx')
save_dataframe_to_excel(df_spx, 'df_spx.xlsx')
# Out:
# Data saved to df_qqq.xlsx
# Data saved to df_spx.xlsx

# %% [markdown]
# ## Understand Index Components

# %% [markdown]
# ### QQQ Components

# %%
#df_qqq = load_dataframe_from_file('df_qqq.pkl')

# Print details of all companies in a compact format
print_all_company_details_compact(df_qqq, rank_by='industry')
display_industry_stats(df)
# Out:
# DataFrame columns: Index(['#', 'Company', 'Symbol', 'Portfolio%', 'Price', 'Chg', '% Chg', '',
#        'Industry'],
#       dtype='object')
# #   | Company                             | Symbol | Portfolio% | Price    | Chg    | % Chg    |  | Industry
# ---------------------------------------------------------------------------------------------------------------------------------------
# 60  | Ross Stores Inc                     | ROST   | 0.33       | 143.99   | -0.41  | (-0.28%) |  | Apparel Retail
# 78  | Lululemon Athletica Inc             | LULU   | 0.24       | 300.18   | -1.49  | (-0.49%) |  | Apparel Retail
# 9   | Tesla Inc                           | TSLA   | 2.62       | 247.71   | 16.45  | (7.11%)  |  | Auto Manufacturers
# 86  | Coca-Cola Europacific Partners PLC  | CCEP   | 0.22       | 73.58    | 0.84   | (1.15%)  |  | Beverages - Non-Alcoholic
# 57  | Monster Beverage Corp               | MNST   | 0.35       | 49.06    | -0.28  | (-0.57%) |  | Beverages - Non-Alcoholic
# 14  | PepsiCo Inc                         | PEP    | 1.5        | 162.60   | -0.98  | (-0.60%) |  | Beverages - Non-Alcoholic
# 66  | Keurig Dr Pepper Inc                | KDP    | 0.3        | 32.93    | 0.14   | (0.44%)  |  | Beverages - Non-Alcoholic
# 67  | Moderna Inc                         | MRNA   | 0.3        | 115.95   | -1.12  | (-0.96%) |  | Biotechnology
# 31  | Regeneron Pharmaceuticals Inc       | REGN   | 0.77       | 1,022.10 | -22.57 | (-2.16%) |  | Biotechnology
# 30  | Vertex Pharmaceuticals Inc          | VRTX   | 0.81       | 469.14   | -4.64  | (-0.98%) |  | Biotechnology
# 19  | Cisco Systems Inc                   | CSCO   | 1.28       | 47.06    | -0.23  | (-0.48%) |  | Communication Equipment
# 40  | Mondelez International Inc          | MDLZ   | 0.58       | 66.49    | 0.46   | (0.70%)  |  | Confectioners
# 27  | Honeywell International Inc         | HON    | 0.92       | 212.03   | -1.20  | (-0.57%) |  | Conglomerates
# 76  | Verisk Analytics Inc                | VRSK   | 0.26       | 273.39   | 1.02   | (0.38%)  |  | Consulting Services
# 2   | Apple Inc                           | AAPL   | 8.59       | 221.07   | 0.80   | (0.36%)  |  | Consumer Electronics
# 52  | PayPal Holdings Inc                 | PYPL   | 0.4        | 59.57    | 0.60   | (1.02%)  |  | Credit Services
# 73  | IDEXX Laboratories Inc              | IDXX   | 0.26       | 477.25   | 0.02   | (0.00%)  |  | Diagnostics & Research
# 102 | GRAIL Inc                           | GRAL   | 0.0        | 15.63    | 0.57   | (3.82%)  |  | Diagnostics & Research
# 100 | Illumina Inc                        | ILMN   | 0.11       | 105.37   | -0.14  | (-0.13%) |  | Diagnostics & Research
# 10  | Costco Wholesale Corp               | COST   | 2.5        | 862.25   | 2.88   | (0.34%)  |  | Discount Stores
# 96  | Dollar Tree Inc                     | DLTR   | 0.16       | 105.98   | -1.14  | (-1.06%) |  | Discount Stores
# 64  | AstraZeneca PLC ADR                 | AZN    | 0.3        | 76.81    | -0.18  | (-0.23%) |  | Drug Manufacturers - General
# 22  | Amgen Inc                           | AMGN   | 1.11       | 308.85   | -1.92  | (-0.62%) |  | Drug Manufacturers - General
# 42  | Gilead Sciences Inc                 | GILD   | 0.57       | 66.70    | -1.70  | (-2.49%) |  | Drug Manufacturers - General
# 84  | Biogen Inc                          | BIIB   | 0.23       | 225.08   | -3.75  | (-1.64%) |  | Drug Manufacturers - General
# 77  | Electronic Arts Inc                 | EA     | 0.25       | 138.42   | -0.46  | (-0.33%) |  | Electronic Gaming & Multimedia
# 95  | Take-Two Interactive Software Inc   | TTWO   | 0.18       | 153.40   | -1.25  | (-0.81%) |  | Electronic Gaming & Multimedia
# 99  | Warner Bros Discovery Inc           | WBD    | 0.12       | 7.26     | 0.05   | (0.76%)  |  | Entertainment
# 11  | Netflix Inc                         | NFLX   | 1.94       | 682.54   | 2.96   | (0.44%)  |  | Entertainment
# 55  | PACCAR Inc                          | PCAR   | 0.36       | 102.07   | 1.16   | (1.15%)  |  | Farm & Heavy Construction Machinery
# 82  | GE HealthCare Technologies Inc      | GEHC   | 0.23       | 77.30    | 0.97   | (1.27%)  |  | Health Information Services
# 80  | Fastenal Co                         | FAST   | 0.24       | 62.69    | -0.07  | (-0.11%) |  | Industrial Distribution
# 90  | CDW Corp/DE                         | CDW    | 0.2        | 218.03   | -1.09  | (-0.50%) |  | Information Technology Services
# 85  | Cognizant Technology Solutions Corp | CTSH   | 0.23       | 68.28    | -0.33  | (-0.49%) |  | Information Technology Services
# 71  | DoorDash Inc                        | DASH   | 0.28       | 107.53   | 0.08   | (0.07%)  |  | Internet Content & Information
# 8   | Alphabet Inc                        | GOOG   | 2.68       | 187.26   | 0.64   | (0.35%)  |  | Internet Content & Information
# 6   | Meta Platforms Inc                  | META   | 4.55       | 509.86   | 0.36   | (0.07%)  |  | Internet Content & Information
# 7   | Alphabet Inc                        | GOOGL  | 2.78       | 185.73   | 0.49   | (0.26%)  |  | Internet Content & Information
# 4   | Amazon.com Inc                      | AMZN   | 5.31       | 197.44   | -2.56  | (-1.28%) |  | Internet Retail
# 39  | PDD Holdings Inc ADR                | PDD    | 0.59       | 137.17   | 3.29   | (2.46%)  |  | Internet Retail
# 44  | MercadoLibre Inc                    | MELI   | 0.54       | 1,590.53 | -5.95  | (-0.37%) |  | Internet Retail
# 46  | Marriott International Inc/MD       | MAR    | 0.46       | 240.13   | 0.15   | (0.06%)  |  | Lodging
# 65  | Dexcom Inc                          | DXCM   | 0.3        | 110.90   | -1.59  | (-1.41%) |  | Medical Devices
# 23  | Intuitive Surgical Inc              | ISRG   | 1.03       | 433.91   | -4.90  | (-1.12%) |  | Medical Instruments & Supplies
# 79  | Diamondback Energy Inc              | FANG   | 0.24       | 206.97   | 2.06   | (1.01%)  |  | Oil & Gas E&P
# 81  | Baker Hughes Co                     | BKR    | 0.23       | 34.32    | -0.37  | (-1.07%) |  | Oil & Gas Equipment & Services
# 75  | Kraft Heinz Co/The                  | KHC    | 0.26       | 32.13    | 0.13   | (0.39%)  |  | Packaged Foods
# 101 | Walgreens Boots Alliance Inc        | WBA    | 0.07       | 11.12    | -0.45  | (-3.92%) |  | Pharmaceutical Retailers
# 49  | CSX Corp                            | CSX    | 0.44       | 33.55    | -0.21  | (-0.64%) |  | Railroads
# 87  | CoStar Group Inc                    | CSGP   | 0.2        | 73.80    | -0.42  | (-0.57%) |  | Real Estate Services
# 41  | Starbucks Corp                      | SBUX   | 0.58       | 76.26    | -0.57  | (-0.74%) |  | Restaurants
# 18  | Applied Materials Inc               | AMAT   | 1.31       | 243.16   | 2.29   | (0.95%)  |  | Semiconductor Equipment & Materials
# 26  | Lam Research Corp                   | LRCX   | 0.93       | 1,082.45 | 9.63   | (0.90%)  |  | Semiconductor Equipment & Materials
# 36  | ASML Holding NV                     | ASML   | 0.63       | 1,070.80 | 22.91  | (2.19%)  |  | Semiconductor Equipment & Materials
# 33  | KLA Corp                            | KLAC   | 0.74       | 852.05   | 12.93  | (1.54%)  |  | Semiconductor Equipment & Materials
# 94  | GLOBALFOUNDRIES Inc                 | GFS    | 0.19       | 50.88    | 0.03   | (0.07%)  |  | Semiconductors
# 89  | ON Semiconductor Corp               | ON     | 0.2        | 72.69    | -0.23  | (-0.32%) |  | Semiconductors
# 98  | ARM Holdings PLC ADR                | ARM    | 0.13       | 167.44   | 3.98   | (2.43%)  |  | Semiconductors
# 51  | Marvell Technology Inc              | MRVL   | 0.41       | 71.88    | 0.28   | (0.38%)  |  | Semiconductors
# 32  | Analog Devices Inc                  | ADI    | 0.75       | 229.33   | 1.08   | (0.48%)  |  | Semiconductors
# 25  | Micron Technology Inc               | MU     | 0.97       | 136.18   | 3.59   | (2.71%)  |  | Semiconductors
# 21  | Texas Instruments Inc               | TXN    | 1.18       | 198.71   | 0.29   | (0.15%)  |  | Semiconductors
# 47  | NXP Semiconductors NV               | NXPI   | 0.45       | 273.78   | 1.73   | (0.64%)  |  | Semiconductors
# 29  | Intel Corp                          | INTC   | 0.88       | 31.20    | 0.13   | (0.40%)  |  | Semiconductors
# 15  | QUALCOMM Inc                        | QCOM   | 1.49       | 203.67   | 3.51   | (1.75%)  |  | Semiconductors
# 5   | Broadcom Inc                        | AVGO   | 5.08       | 1,728.89 | 71.40  | (4.31%)  |  | Semiconductors
# 3   | NVIDIA Corp                         | NVDA   | 7.9        | 127.55   | 4.88   | (3.98%)  |  | Semiconductors
# 12  | Advanced Micro Devices Inc          | AMD    | 1.7        | 163.61   | -0.70  | (-0.43%) |  | Semiconductors
# 59  | Microchip Technology Inc            | MCHP   | 0.33       | 93.73    | 1.66   | (1.81%)  |  | Semiconductors
# 53  | Roper Technologies Inc              | ROP    | 0.4        | 560.45   | -2.66  | (-0.47%) |  | Software - Application
# 68  | Trade Desk Inc/The                  | TTD    | 0.29       | 99.34    | 1.00   | (1.02%)  |  | Software - Application
# 56  | Autodesk Inc                        | ADSK   | 0.35       | 246.31   | -1.56  | (-0.63%) |  | Software - Application
# 93  | ANSYS Inc                           | ANSS   | 0.19       | 326.95   | -0.15  | (-0.05%) |  | Software - Application
# 72  | Datadog Inc                         | DDOG   | 0.27       | 130.99   | -0.76  | (-0.58%) |  | Software - Application
# 92  | Atlassian Corp                      | TEAM   | 0.19       | 182.18   | -0.10  | (-0.05%) |  | Software - Application
# 20  | Intuit Inc                          | INTU   | 1.22       | 660.43   | 4.20   | (0.64%)  |  | Software - Application
# 43  | Cadence Design Systems Inc          | CDNS   | 0.57       | 315.00   | -1.78  | (-0.56%) |  | Software - Application
# 61  | Workday Inc                         | WDAY   | 0.32       | 225.51   | -1.25  | (-0.55%) |  | Software - Application
# 97  | MongoDB Inc                         | MDB    | 0.13       | 264.04   | 4.16   | (1.60%)  |  | Software - Infrastructure
# 13  | Adobe Inc                           | ADBE   | 1.68       | 569.77   | 2.06   | (0.36%)  |  | Software - Infrastructure
# 88  | Zscaler Inc                         | ZS     | 0.2        | 198.25   | 1.59   | (0.81%)  |  | Software - Infrastructure
# 1   | Microsoft Corp                      | MSFT   | 8.78       | 460.15   | 0.87   | (0.19%)  |  | Software - Infrastructure
# 37  | Synopsys Inc                        | SNPS   | 0.62       | 607.53   | -2.13  | (-0.35%) |  | Software - Infrastructure
# 38  | Crowdstrike Holdings Inc            | CRWD   | 0.6        | 386.77   | 1.71   | (0.45%)  |  | Software - Infrastructure
# 63  | Fortinet Inc                        | FTNT   | 0.3        | 60.72    | -0.29  | (-0.48%) |  | Software - Infrastructure
# 34  | Palo Alto Networks Inc              | PANW   | 0.74       | 340.88   | 0.44   | (0.13%)  |  | Software - Infrastructure
# 58  | Copart Inc                          | CPRT   | 0.34       | 53.73    | -0.96  | (-1.76%) |  | Specialty Business Services
# 45  | Cintas Corp                         | CTAS   | 0.47       | 702.23   | -2.11  | (-0.30%) |  | Specialty Business Services
# 17  | Linde PLC                           | LIN    | 1.38       | 432.78   | 2.69   | (0.62%)  |  | Specialty Chemicals
# 54  | O'Reilly Automotive Inc             | ORLY   | 0.4        | 1,019.69 | -17.37 | (-1.67%) |  | Specialty Retail
# 35  | Automatic Data Processing Inc       | ADP    | 0.64       | 236.90   | 0.27   | (0.11%)  |  | Staffing & Employment Services
# 70  | Paychex Inc                         | PAYX   | 0.28       | 117.43   | -0.95  | (-0.80%) |  | Staffing & Employment Services
# 24  | Comcast Corp                        | CMCSA  | 1.0        | 38.06    | -0.10  | (-0.26%) |  | Telecom Services
# 16  | T-Mobile US Inc                     | TMUS   | 1.4        | 177.52   | -2.47  | (-1.37%) |  | Telecom Services
# 69  | Charter Communications Inc          | CHTR   | 0.28       | 300.00   | -3.50  | (-1.15%) |  | Telecom Services
# 28  | Booking Holdings Inc                | BKNG   | 0.88       | 3,915.49 | -0.72  | (-0.02%) |  | Travel Services
# 48  | Airbnb Inc                          | ABNB   | 0.45       | 152.57   | -1.78  | (-1.15%) |  | Travel Services
# 74  | Old Dominion Freight Line Inc       | ODFL   | 0.26       | 182.00   | -0.17  | (-0.09%) |  | Trucking
# 91  | Xcel Energy Inc                     | XEL    | 0.2        | 52.74    | -0.46  | (-0.86%) |  | Utilities - Regulated Electric
# 62  | American Electric Power Co Inc      | AEP    | 0.31       | 87.47    | -0.16  | (-0.18%) |  | Utilities - Regulated Electric
# 83  | Exelon Corp                         | EXC    | 0.23       | 34.66    | 0.13   | (0.36%)  |  | Utilities - Regulated Electric
# 50  | Constellation Energy Corp           | CEG    | 0.43       | 209.22   | 3.07   | (1.49%)  |  | Utilities - Renewable
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Industry                                 |   Number of Companies | Tickers                                                                                                      |
# +==========================================+=======================+==============================================================================================================+
# | Advertising Agencies                     |                     2 | OMC, IPG                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Aerospace & Defense                      |                    12 | GE, RTX, BA, LMT, TDG, GD, NOC, LHX, HWM, AXON, TXT, HII                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Agricultural Inputs                      |                     4 | CTVA, CF, MOS, FMC                                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Airlines                                 |                     4 | DAL, LUV, UAL, AAL                                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Apparel Manufacturing                    |                     1 | RL                                                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Apparel Retail                           |                     3 | TJX, ROST, LULU                                                                                              |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Asset Management                         |                    11 | BLK, BX, KKR, BK, AMP, TROW, STT, NTRS, PFG, IVZ, BEN                                                        |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Auto & Truck Dealerships                 |                     1 | KMX                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Auto Manufacturers                       |                     3 | TSLA, GM, F                                                                                                  |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Auto Parts                               |                     4 | GPC, APTV, LKQ, BWA                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Banks - Diversified                      |                     4 | JPM, BAC, WFC, C                                                                                             |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Banks - Regional                         |                     9 | PNC, USB, TFC, FITB, MTB, HBAN, RF, CFG, KEY                                                                 |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Beverages - Brewers                      |                     1 | TAP                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Beverages - Non-Alcoholic                |                     4 | KO, PEP, MNST, KDP                                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Beverages - Wineries & Distilleries      |                     1 | STZ                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Biotechnology                            |                     5 | VRTX, REGN, MRNA, TECH, INCY                                                                                 |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Building Materials                       |                     2 | MLM, VMC                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Building Products & Equipment            |                     5 | TT, CARR, JCI, BLDR, MAS                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Capital Markets                          |                     5 | GS, MS, SCHW, RJF, MKTX                                                                                      |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Chemicals                                |                     2 | DOW, CE                                                                                                      |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Communication Equipment                  |                     5 | CSCO, MSI, HPE, ZBRA, JNPR                                                                                   |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Computer Hardware                        |                     6 | ANET, SMCI, HPQ, NTAP, WDC, STX                                                                              |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Confectioners                            |                     2 | MDLZ, HSY                                                                                                    |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Conglomerates                            |                     2 | HON, MMM                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Consulting Services                      |                     2 | VRSK, EFX                                                                                                    |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Consumer Electronics                     |                     1 | AAPL                                                                                                         |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Copper                                   |                     1 | FCX                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Credit Services                          |                     7 | V, MA, AXP, PYPL, COF, DFS, SYF                                                                              |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Diagnostics & Research                   |                    11 | TMO, DHR, IDXX, IQV, A, MTD, LH, WAT, DGX, RVTY, CRL                                                         |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Discount Stores                          |                     5 | COST, WMT, TGT, DG, DLTR                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Drug Manufacturers - General             |                     9 | LLY, JNJ, MRK, ABBV, AMGN, PFE, GILD, BMY, BIIB                                                              |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Drug Manufacturers - Specialty & Generic |                     3 | ZTS, VTRS, CTLT                                                                                              |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Electrical Equipment & Parts             |                     1 | HUBB                                                                                                         |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Electronic Components                    |                     4 | APH, TEL, GLW, JBL                                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Electronic Gaming & Multimedia           |                     2 | EA, TTWO                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Engineering & Construction               |                     2 | PWR, J                                                                                                       |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Entertainment                            |                     9 | NFLX, DIS, WBD, LYV, NWSA, FOXA, PARA, FOX, NWS                                                              |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Farm & Heavy Construction Machinery      |                     3 | CAT, DE, PCAR                                                                                                |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Farm Products                            |                     3 | ADM, TSN, BG                                                                                                 |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Financial Data & Stock Exchanges         |                     8 | SPGI, ICE, CME, MCO, MSCI, NDAQ, CBOE, FDS                                                                   |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Food Distribution                        |                     1 | SYY                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Footwear & Accessories                   |                     2 | NKE, DECK                                                                                                    |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Furnishings, Fixtures & Appliances       |                     1 | MHK                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Gold                                     |                     1 | NEM                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Grocery Stores                           |                     1 | KR                                                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Health Information Services              |                     2 | GEHC, SOLV                                                                                                   |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Healthcare Plans                         |                     7 | UNH, ELV, CI, CVS, HUM, CNC, MOH                                                                             |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Home Improvement Retail                  |                     2 | HD, LOW                                                                                                      |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Household & Personal Products            |                     7 | PG, CL, KMB, KVUE, CHD, EL, CLX                                                                              |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Industrial Distribution                  |                     3 | GWW, FAST, POOL                                                                                              |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Information Technology Services          |                    11 | ACN, IBM, FI, FIS, IT, CTSH, CDW, BR, LDOS, JKHY, EPAM                                                       |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Insurance - Diversified                  |                     2 | AIG, ACGL                                                                                                    |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Insurance - Life                         |                     4 | AFL, PRU, MET, GL                                                                                            |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Insurance - Property & Casualty          |                     8 | PGR, CB, TRV, ALL, HIG, CINF, WRB, L                                                                         |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Insurance - Reinsurance                  |                     1 | EG                                                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Insurance - Specialty                    |                     1 | AIZ                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Insurance Brokers                        |                     5 | MMC, AON, AJG, WTW, BRO                                                                                      |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Integrated Freight & Logistics           |                     5 | UPS, FDX, EXPD, JBHT, CHRW                                                                                   |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Internet Content & Information           |                     4 | META, GOOGL, GOOG, MTCH                                                                                      |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Internet Retail                          |                     3 | AMZN, EBAY, ETSY                                                                                             |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Leisure                                  |                     1 | HAS                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Lodging                                  |                     2 | MAR, HLT                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Luxury Goods                             |                     1 | TPR                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Medical Care Facilities                  |                     3 | HCA, UHS, DVA                                                                                                |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Medical Devices                          |                    11 | ABT, SYK, BSX, MDT, EW, DXCM, ZBH, STE, ALGN, PODD, BIO                                                      |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Medical Distribution                     |                     4 | MCK, COR, CAH, HSIC                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Medical Instruments & Supplies           |                     8 | ISRG, BDX, RMD, WST, HOLX, COO, BAX, TFX                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | N/A                                      |                     2 | BRK.B, BF.B                                                                                                  |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Oil & Gas E&P                            |                    10 | COP, EOG, OXY, HES, FANG, DVN, CTRA, EQT, MRO, APA                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Oil & Gas Equipment & Services           |                     3 | SLB, BKR, HAL                                                                                                |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Oil & Gas Integrated                     |                     2 | XOM, CVX                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Oil & Gas Midstream                      |                     4 | WMB, OKE, KMI, TRGP                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Oil & Gas Refining & Marketing           |                     3 | MPC, PSX, VLO                                                                                                |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Packaged Foods                           |                     9 | GIS, KHC, MKC, K, CAG, LW, SJM, CPB, HRL                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Packaging & Containers                   |                     6 | BALL, AVY, PKG, IP, AMCR, WRK                                                                                |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Personal Services                        |                     1 | ROL                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Pharmaceutical Retailers                 |                     1 | WBA                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Pollution & Treatment Controls           |                     1 | VLTO                                                                                                         |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Diversified                       |                     1 | VICI                                                                                                         |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Healthcare Facilities             |                     3 | WELL, VTR, DOC                                                                                               |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Hotel & Motel                     |                     1 | HST                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Industrial                        |                     3 | PLD, PSA, EXR                                                                                                |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Office                            |                     2 | ARE, BXP                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Residential                       |                     7 | AVB, EQR, INVH, ESS, MAA, UDR, CPT                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Retail                            |                     5 | SPG, O, KIM, REG, FRT                                                                                        |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Specialty                         |                     7 | AMT, EQIX, DLR, CCI, IRM, SBAC, WY                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Railroads                                |                     4 | UNP, CSX, NSC, WAB                                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Real Estate Services                     |                     2 | CSGP, CBRE                                                                                                   |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Rental & Leasing Services                |                     1 | URI                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Residential Construction                 |                     4 | DHI, LEN, NVR, PHM                                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Resorts & Casinos                        |                     4 | LVS, MGM, WYNN, CZR                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Restaurants                              |                     6 | MCD, SBUX, CMG, YUM, DRI, DPZ                                                                                |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Scientific & Technical Instruments       |                     5 | FTV, GRMN, KEYS, TDY, TRMB                                                                                   |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Security & Protection Services           |                     1 | ALLE                                                                                                         |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Semiconductor Equipment & Materials      |                     4 | AMAT, LRCX, KLAC, TER                                                                                        |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Semiconductors                           |                    14 | NVDA, AVGO, AMD, QCOM, TXN, MU, INTC, ADI, NXPI, MCHP, MPWR, ON, SWKS, QRVO                                  |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Software - Application                   |                    13 | CRM, INTU, NOW, UBER, CDNS, ROP, ADSK, FICO, ANSS, PTC, TYL, DAY, PAYC                                       |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Software - Infrastructure                |                    13 | MSFT, ADBE, ORCL, PANW, SNPS, CRWD, FTNT, GDDY, CPAY, VRSN, GEN, AKAM, FFIV                                  |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Solar                                    |                     2 | FSLR, ENPH                                                                                                   |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Specialty Business Services              |                     3 | CTAS, CPRT, GPN                                                                                              |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Specialty Chemicals                      |                    10 | LIN, SHW, ECL, APD, DD, PPG, IFF, LYB, ALB, EMN                                                              |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Specialty Industrial Machinery           |                    16 | ETN, PH, ITW, EMR, OTIS, AME, IR, CMI, XYL, ROK, DOV, IEX, NDSN, PNR, AOS, GNRC                              |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Specialty Retail                         |                     6 | ORLY, AZO, TSCO, ULTA, BBY, BBWI                                                                             |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Staffing & Employment Services           |                     2 | ADP, PAYX                                                                                                    |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Steel                                    |                     2 | NUE, STLD                                                                                                    |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Telecom Services                         |                     5 | VZ, CMCSA, T, TMUS, CHTR                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Tobacco                                  |                     2 | PM, MO                                                                                                       |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Tools & Accessories                      |                     2 | SNA, SWK                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Travel Services                          |                     6 | BKNG, ABNB, RCL, CCL, EXPE, NCLH                                                                             |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Trucking                                 |                     1 | ODFL                                                                                                         |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Utilities - Diversified                  |                     2 | SRE, AES                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Utilities - Independent Power Producers  |                     2 | VST, NRG                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Utilities - Regulated Electric           |                    23 | NEE, SO, DUK, AEP, D, PEG, PCG, EXC, ED, XEL, EIX, WEC, DTE, ETR, PPL, FE, ES, CNP, AEE, CMS, LNT, EVRG, PNW |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Utilities - Regulated Gas                |                     2 | ATO, NI                                                                                                      |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Utilities - Regulated Water              |                     1 | AWK                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Utilities - Renewable                    |                     2 | CEG, GEV                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Waste Management                         |                     2 | WM, RSG                                                                                                      |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ### SPX Components

# %%
#df_spx = load_dataframe_from_file('df_spx.pkl')

# Print details of all companies in a compact format
print_all_company_details_compact(df_spx, rank_by='industry')
display_industry_stats(df)
# Out:
# DataFrame columns: Index(['#', 'Company', 'Symbol', 'Portfolio%', 'Price', 'Chg', '% Chg',
#        'Industry'],
#       dtype='object')
# #   | Company                                        | Symbol | Portfolio% | Price    | Chg    | % Chg    | Industry
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# 452 | The Interpublic Group of Companies, Inc.       | IPG    | 0.02       | 28.77    | 0.20   | (0.70%)  | Advertising Agencies
# 363 | Omnicom Group Inc.                             | OMC    | 0.04       | 89.19    | 0.11   | (0.12%)  | Advertising Agencies
# 465 | Huntington Ingalls Industries, Inc.            | HII    | 0.02       | 246.19   | -1.29  | (-0.52%) | Aerospace & Defense
# 382 | Textron, Inc.                                  | TXT    | 0.04       | 86.17    | 0.39   | (0.45%)  | Aerospace & Defense
# 334 | Axon Enterprise, Inc.                          | AXON   | 0.04       | 296.44   | 3.25   | (1.11%)  | Aerospace & Defense
# 124 | Transdigm Group Incorporated                   | TDG    | 0.15       | 1,281.85 | 3.75   | (0.29%)  | Aerospace & Defense
# 138 | General Dynamics Corporation                   | GD     | 0.14       | 285.00   | -0.81  | (-0.28%) | Aerospace & Defense
# 67  | Rtx Corporation                                | RTX    | 0.29       | 100.55   | 0.14   | (0.14%)  | Aerospace & Defense
# 151 | Northrop Grumman Corp.                         | NOC    | 0.13       | 437.30   | -0.07  | (-0.02%) | Aerospace & Defense
# 91  | Lockheed Martin Corp.                          | LMT    | 0.22       | 466.05   | 0.35   | (0.07%)  | Aerospace & Defense
# 45  | General Electric Company                       | GE     | 0.38       | 163.09   | 1.64   | (1.02%)  | Aerospace & Defense
# 263 | Howmet Aerospace Inc.                          | HWM    | 0.07       | 79.35    | 1.28   | (1.64%)  | Aerospace & Defense
# 86  | Boeing Company                                 | BA     | 0.23       | 184.37   | -1.05  | (-0.57%) | Aerospace & Defense
# 196 | L3harris Technologies, Inc.                    | LHX    | 0.09       | 224.49   | 0.89   | (0.40%)  | Aerospace & Defense
# 493 | Fmc Corporation                                | FMC    | 0.02       | 56.15    | 0.53   | (0.96%)  | Agricultural Inputs
# 222 | Corteva, Inc.                                  | CTVA   | 0.08       | 52.50    | -0.27  | (-0.51%) | Agricultural Inputs
# 468 | The Mosaic Company                             | MOS    | 0.02       | 28.00    | 0.23   | (0.83%)  | Agricultural Inputs
# 424 | Cf Industries Holding, Inc.                    | CF     | 0.03       | 70.35    | -0.48  | (-0.68%) | Agricultural Inputs
# 399 | United Airlines Holdings, Inc.                 | UAL    | 0.03       | 48.46    | 0.25   | (0.53%)  | Airlines
# 267 | Delta Air Lines, Inc.                          | DAL    | 0.07       | 47.20    | 0.49   | (1.05%)  | Airlines
# 490 | American Airlines Group Inc.                   | AAL    | 0.02       | 11.14    | 0.08   | (0.77%)  | Airlines
# 380 | Southwest Airlines Co.                         | LUV    | 0.04       | 28.58    | 0.29   | (1.01%)  | Airlines
# 497 | Ralph Lauren Corporation                       | RL     | 0.01       | 175.40   | 6.66   | (3.95%)  | Apparel Manufacturing
# 174 | Ross Stores Inc                                | ROST   | 0.11       | 143.99   | -0.41  | (-0.28%) | Apparel Retail
# 244 | Lululemon Athletica Inc.                       | LULU   | 0.08       | 300.18   | -1.49  | (-0.49%) | Apparel Retail
# 72  | Tjx Companies, Inc.                            | TJX    | 0.27       | 112.22   | 2.02   | (1.83%)  | Apparel Retail
# 193 | Ameriprise Financial, Inc.                     | AMP    | 0.09       | 432.58   | -1.29  | (-0.30%) | Asset Management
# 103 | Blackstone Inc.                                | BX     | 0.19       | 123.58   | 0.37   | (0.30%)  | Asset Management
# 365 | Northern Trust Corp                            | NTRS   | 0.04       | 84.36    | 0.13   | (0.15%)  | Asset Management
# 295 | T Rowe Price Group Inc                         | TROW   | 0.06       | 113.38   | -1.22  | (-1.06%) | Asset Management
# 498 | Franklin Resources, Inc.                       | BEN    | 0.01       | 22.92    | 0.68   | (3.08%)  | Asset Management
# 323 | State Street Corporation                       | STT    | 0.05       | 74.15    | 0.29   | (0.39%)  | Asset Management
# 496 | Invesco Ltd                                    | IVZ    | 0.01       | 15.04    | 0.04   | (0.23%)  | Asset Management
# 125 | Kkr & Co. Inc.                                 | KKR    | 0.15       | 106.16   | 0.23   | (0.22%)  | Asset Management
# 367 | Principal Financial Group, Inc.                | PFG    | 0.04       | 78.34    | -0.92  | (-1.16%) | Asset Management
# 188 | Bank of New York Mellon Corporation            | BK     | 0.1        | 60.47    | -0.03  | (-0.06%) | Asset Management
# 84  | Blackrock, Inc.                                | BLK    | 0.24       | 783.75   | -5.38  | (-0.68%) | Asset Management
# 443 | Carmax Inc.                                    | KMX    | 0.03       | 72.42    | -0.86  | (-1.18%) | Auto & Truck Dealerships
# 169 | Ford Motor Company                             | F      | 0.11       | 12.86    | -0.01  | (-0.12%) | Auto Manufacturers
# 11  | Tesla, Inc.                                    | TSLA   | 1.39       | 247.34   | 16.08  | (6.95%)  | Auto Manufacturers
# 161 | General Motors Company                         | GM     | 0.12       | 46.64    | -0.32  | (-0.67%) | Auto Manufacturers
# 351 | Aptiv Plc                                      | APTV   | 0.04       | 69.76    | 0.31   | (0.45%)  | Auto Parts
# 348 | Genuine Parts Company                          | GPC    | 0.04       | 133.55   | -2.44  | (-1.79%) | Auto Parts
# 449 | Lkq Corporation                                | LKQ    | 0.02       | 41.52    | -0.47  | (-1.12%) | Auto Parts
# 486 | Borgwarner Inc.                                | BWA    | 0.02       | 32.10    | 0.33   | (1.05%)  | Auto Parts
# 34  | Wells Fargo & Co.                              | WFC    | 0.46       | 60.73    | -0.24  | (-0.39%) | Banks - Diversified
# 12  | Jpmorgan Chase & Co.                           | JPM    | 1.3        | 208.60   | -0.23  | (-0.11%) | Banks - Diversified
# 25  | Bank of America Corporation                    | BAC    | 0.6        | 40.93    | 0.00   | (0.00%)  | Banks - Diversified
# 75  | Citigroup Inc.                                 | C      | 0.27       | 64.48    | -0.20  | (-0.31%) | Banks - Diversified
# 355 | Regions Financial Corp.                        | RF     | 0.04       | 19.95    | -0.14  | (-0.70%) | Banks - Regional
# 418 | Keycorp                                        | KEY    | 0.03       | 14.31    | -0.13  | (-0.87%) | Banks - Regional
# 166 | Truist Financial Corporation                   | TFC    | 0.11       | 38.81    | -0.75  | (-1.90%) | Banks - Regional
# 298 | Fifth Third Bancorp                            | FITB   | 0.05       | 36.77    | -0.21  | (-0.57%) | Banks - Regional
# 299 | M&t Bank Corp.                                 | MTB    | 0.05       | 151.49   | -0.24  | (-0.16%) | Banks - Regional
# 145 | U.S. Bancorp                                   | USB    | 0.13       | 39.53    | -0.45  | (-1.11%) | Banks - Regional
# 143 | Pnc Financial Services Group                   | PNC    | 0.14       | 157.79   | -1.05  | (-0.66%) | Banks - Regional
# 349 | Huntington Bancshares Inc                      | HBAN   | 0.04       | 13.10    | -0.11  | (-0.83%) | Banks - Regional
# 379 | Citizens Financial Group, Inc.                 | CFG    | 0.04       | 36.72    | 0.34   | (0.93%)  | Banks - Regional
# 466 | Molson Coors Beverage Company Class B          | TAP    | 0.02       | 50.78    | 0.21   | (0.43%)  | Beverages - Brewers
# 247 | Keurig Dr Pepper Inc.                          | KDP    | 0.07       | 32.93    | 0.14   | (0.44%)  | Beverages - Non-Alcoholic
# 30  | Coca-Cola Company                              | KO     | 0.53       | 63.34    | 0.19   | (0.30%)  | Beverages - Non-Alcoholic
# 32  | Pepsico, Inc.                                  | PEP    | 0.49       | 162.60   | -0.98  | (-0.60%) | Beverages - Non-Alcoholic
# 240 | Monster Beverage Corporation                   | MNST   | 0.08       | 49.06    | -0.28  | (-0.57%) | Beverages - Non-Alcoholic
# 201 | Constellation Brands, Inc.                     | STZ    | 0.09       | 249.80   | -9.15  | (-3.53%) | Beverages - Wineries & Distilleries
# 215 | Moderna, Inc.                                  | MRNA   | 0.08       | 115.95   | -1.12  | (-0.96%) | Biotechnology
# 82  | Regeneron Pharmaceuticals Inc                  | REGN   | 0.24       | 1,022.10 | -22.57 | (-2.16%) | Biotechnology
# 451 | Incyte Genomics Inc                            | INCY   | 0.02       | 57.67    | -1.35  | (-2.29%) | Biotechnology
# 450 | Bio-Techne Corp.                               | TECH   | 0.02       | 71.44    | 0.20   | (0.27%)  | Biotechnology
# 77  | Vertex Pharmaceuticals Inc                     | VRTX   | 0.26       | 469.14   | -4.64  | (-0.98%) | Biotechnology
# 255 | Vulcan Materials Company                       | VMC    | 0.07       | 250.79   | 5.72   | (2.33%)  | Building Materials
# 252 | Martin Marietta Materials                      | MLM    | 0.07       | 533.09   | -1.74  | (-0.33%) | Building Materials
# 407 | Masco Corporation                              | MAS    | 0.03       | 64.75    | 0.00   | (0.00%)  | Building Products & Equipment
# 191 | Johnson Controls International Plc             | JCI    | 0.1        | 66.83    | 0.51   | (0.77%)  | Building Products & Equipment
# 384 | Builders Firstsource, Inc.                     | BLDR   | 0.04       | 134.69   | -0.06  | (-0.04%) | Building Products & Equipment
# 165 | Carrier Global Corporation                     | CARR   | 0.11       | 63.18    | 0.35   | (0.56%)  | Building Products & Equipment
# 119 | Trane Technologies Plc                         | TT     | 0.16       | 331.08   | 6.25   | (1.92%)  | Building Products & Equipment
# 488 | Marketaxess Holdings Inc.                      | MKTX   | 0.02       | 200.90   | 7.09   | (3.66%)  | Capital Markets
# 318 | Raymond James Financial, Inc.                  | RJF    | 0.05       | 120.80   | -1.28  | (-1.05%) | Capital Markets
# 71  | Morgan Stanley                                 | MS     | 0.27       | 100.11   | 0.45   | (0.46%)  | Capital Markets
# 55  | Goldman Sachs Group Inc.                       | GS     | 0.32       | 467.76   | 2.15   | (0.46%)  | Capital Markets
# 83  | The Charles Schwab Corporation                 | SCHW   | 0.24       | 74.00    | -0.15  | (-0.20%) | Capital Markets
# 420 | Celanese Corporation                           | CE     | 0.03       | 134.96   | 2.08   | (1.56%)  | Chemicals
# 226 | Dow Inc.                                       | DOW    | 0.08       | 52.91    | 0.20   | (0.38%)  | Chemicals
# 440 | Juniper Networks Inc                           | JNPR   | 0.03       | 36.44    | -0.13  | (-0.36%) | Communication Equipment
# 395 | Zebra Technologies Corporation                 | ZBRA   | 0.03       | 314.03   | 4.00   | (1.29%)  | Communication Equipment
# 38  | Cisco Systems, Inc.                            | CSCO   | 0.41       | 47.06    | -0.23  | (-0.48%) | Communication Equipment
# 140 | Motorola Solutions, Inc.                       | MSI    | 0.14       | 385.64   | -1.12  | (-0.29%) | Communication Equipment
# 288 | Hewlett Packard Enterprise Company             | HPE    | 0.06       | 20.62    | -0.51  | (-2.39%) | Communication Equipment
# 266 | Hp Inc.                                        | HPQ    | 0.07       | 34.91    | 0.11   | (0.32%)  | Computer Hardware
# 340 | Seagate Technology Holdings Plcs               | STX    | 0.04       | 101.52   | -1.61  | (-1.57%) | Computer Hardware
# 197 | Super Micro Computer, Inc.                     | SMCI   | 0.09       | 846.10   | 8.93   | (1.07%)  | Computer Hardware
# 300 | Western Digital Corp.                          | WDC    | 0.05       | 77.80    | -0.25  | (-0.33%) | Computer Hardware
# 99  | Arista Networks                                | ANET   | 0.19       | 364.63   | 7.62   | (2.13%)  | Computer Hardware
# 291 | Netapp, Inc                                    | NTAP   | 0.06       | 129.89   | 0.00   | (0.00%)  | Computer Hardware
# 101 | Mondelez International, Inc. Class A           | MDLZ   | 0.19       | 66.49    | 0.46   | (0.70%)  | Confectioners
# 286 | The Hershey Company                            | HSY    | 0.06       | 183.75   | -0.90  | (-0.49%) | Confectioners
# 157 | 3m Company                                     | MMM    | 0.12       | 101.57   | -0.05  | (-0.05%) | Conglomerates
# 62  | Honeywell International, Inc.                  | HON    | 0.3        | 212.03   | -1.20  | (-0.57%) | Conglomerates
# 271 | Equifax, Incorporated                          | EFX    | 0.06       | 240.50   | 0.53   | (0.22%)  | Consulting Services
# 214 | Verisk Analytics, Inc.                         | VRSK   | 0.08       | 273.39   | 1.02   | (0.38%)  | Consulting Services
# 2   | Apple Inc.                                     | AAPL   | 6.86       | 221.07   | 0.80   | (0.36%)  | Consumer Electronics
# 126 | Freeport-Mcmoran Inc.                          | FCX    | 0.15       | 50.65    | 1.94   | (3.98%)  | Copper
# 162 | Capital One Financial                          | COF    | 0.12       | 138.88   | -1.60  | (-1.14%) | Credit Services
# 147 | Paypal Holdings, Inc.                          | PYPL   | 0.13       | 59.57    | 0.60   | (1.02%)  | Credit Services
# 15  | Visa Inc.                                      | V      | 0.91       | 268.95   | 0.72   | (0.27%)  | Credit Services
# 65  | American Express Company                       | AXP    | 0.29       | 235.48   | -0.49  | (-0.21%) | Credit Services
# 344 | Synchrony Financial                            | SYF    | 0.04       | 47.35    | -0.68  | (-1.42%) | Credit Services
# 18  | Mastercard Incorporated                        | MA     | 0.79       | 444.84   | 0.19   | (0.04%)  | Credit Services
# 249 | Discover Financial Services                    | DFS    | 0.07       | 127.13   | -6.41  | (-4.80%) | Credit Services
# 428 | Revvity, Inc.                                  | RVTY   | 0.03       | 102.49   | 0.48   | (0.47%)  | Diagnostics & Research
# 36  | Thermo Fisher Scientific, Inc.                 | TMO    | 0.44       | 537.47   | 3.54   | (0.66%)  | Diagnostics & Research
# 457 | Charles River Laboratories International, Inc. | CRL    | 0.02       | 201.06   | -0.42  | (-0.21%) | Diagnostics & Research
# 219 | Iqvia Holdings Inc.                            | IQV    | 0.08       | 208.51   | 1.03   | (0.50%)  | Diagnostics & Research
# 209 | Idexx Laboratories Inc                         | IDXX   | 0.09       | 477.25   | 0.02   | (0.00%)  | Diagnostics & Research
# 227 | Agilent Technologies Inc.                      | A      | 0.08       | 126.17   | 0.39   | (0.31%)  | Diagnostics & Research
# 372 | Labcorp Holdings Inc.                          | LH     | 0.04       | 204.02   | 1.29   | (0.64%)  | Diagnostics & Research
# 51  | Danaher Corporation                            | DHR    | 0.34       | 240.08   | -0.34  | (-0.14%) | Diagnostics & Research
# 403 | Quest Diagnostics Inc.                         | DGX    | 0.03       | 142.26   | 5.62   | (4.12%)  | Diagnostics & Research
# 275 | Mettler-Toledo International                   | MTD    | 0.06       | 1,352.67 | -4.40  | (-0.32%) | Diagnostics & Research
# 381 | Waters Corp                                    | WAT    | 0.04       | 289.71   | 5.21   | (1.83%)  | Diagnostics & Research
# 131 | Target Corporation                             | TGT    | 0.15       | 144.82   | -0.57  | (-0.39%) | Discount Stores
# 17  | Costco Wholesale Corp                          | COST   | 0.82       | 862.25   | 2.88   | (0.34%)  | Discount Stores
# 24  | Walmart Inc.                                   | WMT    | 0.63       | 68.18    | 0.11   | (0.16%)  | Discount Stores
# 282 | Dollar General Corp.                           | DG     | 0.06       | 125.48   | -4.00  | (-3.09%) | Discount Stores
# 324 | Dollar Tree Inc.                               | DLTR   | 0.05       | 105.98   | -1.14  | (-1.06%) | Discount Stores
# 107 | Gilead Sciences Inc                            | GILD   | 0.18       | 66.70    | -1.70  | (-2.49%) | Drug Manufacturers - General
# 9   | Eli Lilly & Co.                                | LLY    | 1.56       | 896.53   | -10.19 | (-1.12%) | Drug Manufacturers - General
# 251 | Biogen Inc.                                    | BIIB   | 0.07       | 225.08   | -3.75  | (-1.64%) | Drug Manufacturers - General
# 19  | Johnson & Johnson                              | JNJ    | 0.76       | 145.60   | -0.43  | (-0.29%) | Drug Manufacturers - General
# 53  | Pfizer Inc.                                    | PFE    | 0.34       | 27.74    | -0.09  | (-0.34%) | Drug Manufacturers - General
# 21  | Merck & Co., Inc.                              | MRK    | 0.7        | 125.65   | -2.07  | (-1.62%) | Drug Manufacturers - General
# 110 | Bristol-Myers Squibb Co.                       | BMY    | 0.18       | 40.12    | -0.33  | (-0.82%) | Drug Manufacturers - General
# 22  | Abbvie Inc.                                    | ABBV   | 0.63       | 164.00   | -1.96  | (-1.18%) | Drug Manufacturers - General
# 47  | Amgen Inc                                      | AMGN   | 0.36       | 308.85   | -1.92  | (-0.62%) | Drug Manufacturers - General
# 429 | Viatris Inc.                                   | VTRS   | 0.03       | 10.39    | -0.04  | (-0.38%) | Drug Manufacturers - Specialty & Generic
# 113 | Zoetis Inc.                                    | ZTS    | 0.17       | 174.25   | -0.56  | (-0.32%) | Drug Manufacturers - Specialty & Generic
# 461 | Catalent, Inc.                                 | CTLT   | 0.02       | 56.38    | 0.17   | (0.31%)  | Drug Manufacturers - Specialty & Generic
# 345 | Hubbell Incorporated                           | HUBB   | 0.04       | 371.13   | 5.32   | (1.45%)  | Electrical Equipment & Parts
# 421 | Jabil Inc.                                     | JBL    | 0.03       | 110.12   | 1.58   | (1.46%)  | Electronic Components
# 186 | Te Connectivity Ltd                            | TEL    | 0.1        | 151.00   | 1.06   | (0.71%)  | Electronic Components
# 273 | Corning Incorporated                           | GLW    | 0.06       | 38.39    | 0.00   | (0.00%)  | Electronic Components
# 111 | Amphenol Corporation                           | APH    | 0.17       | 67.62    | 0.05   | (0.08%)  | Electronic Components
# 248 | Electronic Arts Inc                            | EA     | 0.07       | 138.42   | -0.46  | (-0.33%) | Electronic Gaming & Multimedia
# 307 | Take-Two Interactive Software Inc              | TTWO   | 0.05       | 153.40   | -1.25  | (-0.81%) | Electronic Gaming & Multimedia
# 366 | Jacobs Solutions Inc.                          | J      | 0.04       | 138.42   | 0.65   | (0.47%)  | Engineering & Construction
# 234 | Quanta Services, Inc.                          | PWR    | 0.08       | 254.49   | 6.71   | (2.71%)  | Engineering & Construction
# 501 | Paramount Global Class B                       | PARA   | 0.01       | 11.48    | 0.76   | (7.09%)  | Entertainment
# 455 | News Corporation Class A                       | NWSA   | 0.02       | 27.67    | 0.04   | (0.14%)  | Entertainment
# 414 | Live Nation Entertainment Inc.                 | LYV    | 0.03       | 94.61    | -2.09  | (-2.16%) | Entertainment
# 393 | Warner Bros. Discovery, Inc. Series a          | WBD    | 0.03       | 7.26     | 0.05   | (0.76%)  | Entertainment
# 477 | Fox Corporation Class A                        | FOXA   | 0.02       | 34.23    | -0.25  | (-0.74%) | Entertainment
# 502 | Fox Corporation Class B                        | FOX    | 0.01       | 32.25    | -0.05  | (-0.17%) | Entertainment
# 503 | News Corporation Class B                       | NWS    | 0.01       | 28.51    | 0.09   | (0.32%)  | Entertainment
# 23  | Netflix Inc                                    | NFLX   | 0.63       | 682.54   | 2.96   | (0.44%)  | Entertainment
# 43  | The Walt Disney Company                        | DIS    | 0.39       | 98.66    | 0.67   | (0.68%)  | Entertainment
# 164 | Paccar Inc                                     | PCAR   | 0.11       | 102.07   | 1.16   | (1.15%)  | Farm & Heavy Construction Machinery
# 94  | Deere & Company                                | DE     | 0.2        | 362.60   | -2.35  | (-0.64%) | Farm & Heavy Construction Machinery
# 50  | Caterpillar Inc.                               | CAT    | 0.35       | 330.70   | 2.94   | (0.90%)  | Farm & Heavy Construction Machinery
# 387 | Tyson Foods, Inc.                              | TSN    | 0.04       | 57.25    | 0.03   | (0.05%)  | Farm Products
# 261 | Archer Daniels Midland Company                 | ADM    | 0.07       | 62.17    | 0.04   | (0.06%)  | Farm Products
# 392 | Bunge Global Sa                                | BG     | 0.03       | 110.39   | 0.01   | (0.00%)  | Farm Products
# 60  | S&p Global Inc.                                | SPGI   | 0.31       | 449.24   | -1.21  | (-0.27%) | Financial Data & Stock Exchanges
# 123 | Cme Group Inc.                                 | CME    | 0.15       | 196.02   | -1.06  | (-0.54%) | Financial Data & Stock Exchanges
# 112 | Intercontinental Exchange  Inc.                | ICE    | 0.17       | 141.33   | 0.50   | (0.36%)  | Financial Data & Stock Exchanges
# 359 | Cboe Global Markets, Inc.                      | CBOE   | 0.04       | 171.00   | -0.39  | (-0.23%) | Financial Data & Stock Exchanges
# 398 | Factset Research Systems                       | FDS    | 0.03       | 416.91   | 0.89   | (0.22%)  | Financial Data & Stock Exchanges
# 212 | Msci, Inc.                                     | MSCI   | 0.08       | 491.48   | 0.06   | (0.01%)  | Financial Data & Stock Exchanges
# 320 | Nasdaq, Inc.                                   | NDAQ   | 0.05       | 60.03    | 0.07   | (0.12%)  | Financial Data & Stock Exchanges
# 132 | Moody's Corporation                            | MCO    | 0.14       | 425.98   | -0.03  | (-0.01%) | Financial Data & Stock Exchanges
# 239 | Sysco Corporation                              | SYY    | 0.08       | 70.75    | 0.16   | (0.23%)  | Food Distribution
# 310 | Deckers Outdoor Corp                           | DECK   | 0.05       | 927.55   | -13.09 | (-1.39%) | Footwear & Accessories
# 98  | Nike, Inc.                                     | NKE    | 0.2        | 75.25    | -0.79  | (-1.04%) | Footwear & Accessories
# 499 | Mohawk Industries, Inc.                        | MHK    | 0.01       | 109.30   | -1.03  | (-0.94%) | Furnishings, Fixtures & Appliances
# 177 | Newmont Corporation                            | NEM    | 0.1        | 43.27    | 1.56   | (3.73%)  | Gold
# 253 | The Kroger Co.                                 | KR     | 0.07       | 50.78    | 0.34   | (0.68%)  | Grocery Stores
# 257 | Ge Healthcare Technologies Inc.                | GEHC   | 0.07       | 77.30    | 0.97   | (1.27%)  | Health Information Services
# 491 | Solventum Corporation                          | SOLV   | 0.02       | 50.91    | -0.70  | (-1.35%) | Health Information Services
# 14  | Unitedhealth Group Incorporated                | UNH    | 0.99       | 489.89   | -8.36  | (-1.68%) | Healthcare Plans
# 378 | Molina Healthcare, Inc.                        | MOH    | 0.04       | 296.32   | 4.31   | (1.48%)  | Healthcare Plans
# 238 | Centene Corporation                            | CNC    | 0.08       | 66.75    | 0.56   | (0.85%)  | Healthcare Plans
# 73  | Elevance Health, Inc.                          | ELV    | 0.27       | 529.92   | -6.00  | (-1.12%) | Healthcare Plans
# 97  | The Cigna Group                                | CI     | 0.2        | 325.44   | -0.48  | (-0.15%) | Healthcare Plans
# 121 | Cvs Health Corporation                         | CVS    | 0.16       | 56.75    | -0.78  | (-1.35%) | Healthcare Plans
# 190 | Humana Inc.                                    | HUM    | 0.1        | 363.75   | -11.07 | (-2.95%) | Healthcare Plans
# 20  | Home Depot, Inc.                               | HD     | 0.72       | 333.65   | -1.32  | (-0.39%) | Home Improvement Retail
# 76  | Lowe's Companies Inc.                          | LOW    | 0.26       | 213.26   | -0.44  | (-0.21%) | Home Improvement Retail
# 385 | Clorox Company                                 | CLX    | 0.04       | 133.44   | -0.11  | (-0.08%) | Household & Personal Products
# 241 | Kenvue Inc.                                    | KVUE   | 0.08       | 18.29    | 0.05   | (0.25%)  | Household & Personal Products
# 114 | Colgate-Palmolive Company                      | CL     | 0.17       | 95.88    | -0.24  | (-0.25%) | Household & Personal Products
# 306 | The Estee Lauder Companies Inc. Class A        | EL     | 0.05       | 106.63   | 0.75   | (0.71%)  | Household & Personal Products
# 294 | Church & Dwight Co., Inc.                      | CHD    | 0.06       | 105.10   | -0.34  | (-0.32%) | Household & Personal Products
# 181 | Kimberly-Clark Corp.                           | KMB    | 0.1        | 135.27   | -2.72  | (-1.97%) | Household & Personal Products
# 16  | Procter & Gamble Company                       | PG     | 0.84       | 163.75   | -0.15  | (-0.09%) | Household & Personal Products
# 235 | Fastenal Co                                    | FAST   | 0.08       | 62.69    | -0.07  | (-0.11%) | Industrial Distribution
# 206 | W.W. Grainger, Inc.                            | GWW    | 0.09       | 914.66   | -3.32  | (-0.36%) | Industrial Distribution
# 441 | Pool Corporation                               | POOL   | 0.03       | 300.73   | -0.67  | (-0.22%) | Industrial Distribution
# 104 | Fiserv, Inc.                                   | FI     | 0.19       | 148.57   | -0.82  | (-0.55%) | Information Technology Services
# 272 | Cdw Corporation                                | CDW    | 0.06       | 218.02   | -1.11  | (-0.50%) | Information Technology Services
# 341 | Leidos Holdings, Inc.                          | LDOS   | 0.04       | 146.70   | 0.83   | (0.57%)  | Information Technology Services
# 243 | Gartner, Inc.                                  | IT     | 0.08       | 448.25   | 2.13   | (0.48%)  | Information Technology Services
# 49  | International Business Machines Corporation    | IBM    | 0.35       | 175.62   | -1.69  | (-0.95%) | Information Technology Services
# 199 | Fidelity National Information Services, Inc.   | FIS    | 0.09       | 74.32    | -0.91  | (-1.21%) | Information Technology Services
# 315 | Broadridge Financial Solutions Inc             | BR     | 0.05       | 199.42   | 1.13   | (0.57%)  | Information Technology Services
# 456 | Epam Systems, Inc.                             | EPAM   | 0.02       | 185.28   | 2.00   | (1.09%)  | Information Technology Services
# 437 | Henry (Jack) & Associates                      | JKHY   | 0.03       | 163.65   | -0.11  | (-0.07%) | Information Technology Services
# 39  | Accenture Plc                                  | ACN    | 0.41       | 305.39   | 1.56   | (0.51%)  | Information Technology Services
# 246 | Cognizant Technology Solutions                 | CTSH   | 0.07       | 68.28    | -0.33  | (-0.49%) | Information Technology Services
# 223 | Arch Capital Group Ltd                         | ACGL   | 0.08       | 97.63    | -2.38  | (-2.38%) | Insurance - Diversified
# 170 | American International Group, Inc.             | AIG    | 0.11       | 75.12    | -0.21  | (-0.28%) | Insurance - Diversified
# 200 | Metlife, Inc.                                  | MET    | 0.09       | 70.21    | 0.16   | (0.24%)  | Insurance - Life
# 183 | Aflac Inc.                                     | AFL    | 0.1        | 89.08    | -0.35  | (-0.39%) | Insurance - Life
# 492 | Globe Life Inc.                                | GL     | 0.02       | 82.40    | -0.69  | (-0.82%) | Insurance - Life
# 195 | Prudential Financial, Inc.                     | PRU    | 0.09       | 118.56   | 0.01   | (0.01%)  | Insurance - Life
# 390 | W.R. Berkley Corporation                       | WRB    | 0.03       | 79.17    | -0.04  | (-0.06%) | Insurance - Property & Casualty
# 415 | Loews Corporation                              | L      | 0.03       | 74.39    | -0.55  | (-0.74%) | Insurance - Property & Casualty
# 182 | The Travelers Companies, Inc.                  | TRV    | 0.1        | 203.50   | -0.16  | (-0.08%) | Insurance - Property & Casualty
# 198 | The Allstate Corporation                       | ALL    | 0.09       | 160.50   | 0.32   | (0.20%)  | Insurance - Property & Casualty
# 74  | Progressive Corporation                        | PGR    | 0.27       | 206.31   | -4.81  | (-2.28%) | Insurance - Property & Casualty
# 354 | Cincinnati Financial Corp                      | CINF   | 0.04       | 116.71   | -2.14  | (-1.80%) | Insurance - Property & Casualty
# 269 | The Hartford Financial Services Group, Inc.    | HIG    | 0.06       | 99.60    | -0.43  | (-0.43%) | Insurance - Property & Casualty
# 89  | Chubb Limited                                  | CB     | 0.22       | 255.15   | -0.42  | (-0.16%) | Insurance - Property & Casualty
# 394 | Everest Group, Ltd.                            | EG     | 0.03       | 372.53   | 2.86   | (0.77%)  | Insurance - Reinsurance
# 471 | Assurant, Inc.                                 | AIZ    | 0.02       | 163.91   | -1.94  | (-1.17%) | Insurance - Specialty
# 289 | Willis Towers Watson Public Limited Companys   | WTW    | 0.06       | 260.34   | -1.76  | (-0.67%) | Insurance Brokers
# 330 | Brown & Brown, Inc.                            | BRO    | 0.05       | 90.14    | 0.49   | (0.55%)  | Insurance Brokers
# 88  | Marsh & Mclennan Companies, Inc.               | MMC    | 0.23       | 212.90   | 0.91   | (0.43%)  | Insurance Brokers
# 139 | Aon Plc Class A                                | AON    | 0.14       | 294.91   | -0.66  | (-0.22%) | Insurance Brokers
# 156 | Arthur J. Gallagher & Co.                      | AJG    | 0.12       | 262.82   | 0.81   | (0.31%)  | Insurance Brokers
# 462 | C.H. Robinson Worldwide, Inc.                  | CHRW   | 0.02       | 87.48    | 1.32   | (1.54%)  | Integrated Freight & Logistics
# 375 | Expeditors International of Washington, Inc.   | EXPD   | 0.04       | 123.94   | 2.72   | (2.25%)  | Integrated Freight & Logistics
# 423 | Jb Hunt Transport Services Inc                 | JBHT   | 0.03       | 158.05   | -1.37  | (-0.86%) | Integrated Freight & Logistics
# 130 | Fedex Corporation                              | FDX    | 0.15       | 293.68   | -4.55  | (-1.52%) | Integrated Freight & Logistics
# 92  | United Parcel Service, Inc. Class B            | UPS    | 0.21       | 135.54   | 0.63   | (0.47%)  | Integrated Freight & Logistics
# 6   | Alphabet Inc. Class A                          | GOOGL  | 2.35       | 185.73   | 0.49   | (0.26%)  | Internet Content & Information
# 5   | Meta Platforms, Inc. Class A                   | META   | 2.41       | 509.86   | 0.36   | (0.07%)  | Internet Content & Information
# 7   | Alphabet Inc. Class C                          | GOOG   | 1.97       | 187.23   | 0.62   | (0.33%)  | Internet Content & Information
# 480 | Match Group, Inc                               | MTCH   | 0.02       | 29.49    | 0.04   | (0.12%)  | Internet Content & Information
# 4   | Amazon.com Inc                                 | AMZN   | 3.96       | 197.43   | -2.57  | (-1.28%) | Internet Retail
# 290 | Ebay Inc                                       | EBAY   | 0.06       | 52.54    | -0.71  | (-1.33%) | Internet Retail
# 494 | Etsy, Inc.                                     | ETSY   | 0.02       | 58.24    | -0.02  | (-0.03%) | Internet Retail
# 489 | Hasbro, Inc.                                   | HAS    | 0.02       | 56.98    | -0.09  | (-0.15%) | Leisure
# 155 | Marriot International Class A                  | MAR    | 0.12       | 240.13   | 0.15   | (0.06%)  | Lodging
# 160 | Hilton Worldwide Holdings Inc.                 | HLT    | 0.12       | 216.18   | 0.58   | (0.27%)  | Lodging
# 467 | Tapestry, Inc.                                 | TPR    | 0.02       | 40.28    | -0.26  | (-0.65%) | Luxury Goods
# 484 | Davita Inc.                                    | DVA    | 0.02       | 139.25   | 0.80   | (0.58%)  | Medical Care Facilities
# 146 | Hca Healthcare, Inc.                           | HCA    | 0.13       | 326.07   | 6.37   | (1.99%)  | Medical Care Facilities
# 448 | Universal Health Services, Inc. Class B        | UHS    | 0.02       | 185.14   | 0.41   | (0.22%)  | Medical Care Facilities
# 90  | Medtronic Plc                                  | MDT    | 0.22       | 77.21    | -0.17  | (-0.21%) | Medical Devices
# 500 | Bio-Rad Laboratories, Inc.Class A              | BIO    | 0.01       | 270.04   | 2.49   | (0.93%)  | Medical Devices
# 81  | Boston Scientific Corp.                        | BSX    | 0.24       | 76.75    | 0.20   | (0.26%)  | Medical Devices
# 79  | Stryker Corporation                            | SYK    | 0.24       | 333.00   | -1.30  | (-0.39%) | Medical Devices
# 325 | Zimmer Biomet Holdings, Inc.                   | ZBH    | 0.05       | 106.78   | 0.51   | (0.48%)  | Medical Devices
# 159 | Edwards Lifesciences Corp                      | EW     | 0.12       | 91.11    | -0.12  | (-0.13%) | Medical Devices
# 192 | Dexcom, Inc.                                   | DXCM   | 0.1        | 110.90   | -1.59  | (-1.41%) | Medical Devices
# 328 | Steris Plc                                     | STE    | 0.05       | 217.50   | -0.84  | (-0.39%) | Medical Devices
# 376 | Align Technology Inc                           | ALGN   | 0.04       | 242.90   | 3.16   | (1.32%)  | Medical Devices
# 42  | Abbott Laboratories                            | ABT    | 0.39       | 102.24   | -0.96  | (-0.93%) | Medical Devices
# 413 | Insulet Corporation                            | PODD   | 0.03       | 196.66   | -0.53  | (-0.27%) | Medical Devices
# 118 | Mckesson Corporation                           | MCK    | 0.16       | 579.60   | -5.23  | (-0.89%) | Medical Distribution
# 314 | Cardinal Health, Inc.                          | CAH    | 0.05       | 95.71    | -0.83  | (-0.86%) | Medical Distribution
# 474 | Henry Schein Inc                               | HSIC   | 0.02       | 64.51    | -1.09  | (-1.67%) | Medical Distribution
# 224 | Cencora, Inc.                                  | COR    | 0.08       | 222.54   | 0.03   | (0.01%)  | Medical Distribution
# 370 | Hologic Inc                                    | HOLX   | 0.04       | 73.44    | -0.09  | (-0.12%) | Medical Instruments & Supplies
# 463 | Teleflex Incorporated                          | TFX    | 0.02       | 211.43   | 0.18   | (0.09%)  | Medical Instruments & Supplies
# 134 | Becton, Dickinson and Co.                      | BDX    | 0.14       | 228.70   | -0.54  | (-0.24%) | Medical Instruments & Supplies
# 285 | Resmed Inc.                                    | RMD    | 0.06       | 192.50   | 3.15   | (1.66%)  | Medical Instruments & Supplies
# 311 | West Pharmaceutical Services, Inc.             | WST    | 0.05       | 321.14   | -1.46  | (-0.45%) | Medical Instruments & Supplies
# 54  | Intuitive Surgical Inc.                        | ISRG   | 0.34       | 433.91   | -4.90  | (-1.12%) | Medical Instruments & Supplies
# 374 | The Cooper Companies, Inc.                     | COO    | 0.04       | 85.51    | -1.00  | (-1.16%) | Medical Instruments & Supplies
# 383 | Baxter International Inc.                      | BAX    | 0.04       | 33.12    | 0.27   | (0.82%)  | Medical Instruments & Supplies
# 8   | Berkshire Hathaway Class B                     | BRK.B  | 1.59       | 405.78   | -1.33  | (-0.33%) | N/A
# 483 | Brown-Forman Corporation Class B               | BF.B   | 0.02       | 43.00    | 0.52   | (1.22%)  | N/A
# 204 | Hess Corporation                               | HES    | 0.09       | 149.49   | 0.57   | (0.38%)  | Oil & Gas E&P
# 454 | Apa Corporation                                | APA    | 0.02       | 29.48    | 0.12   | (0.39%)  | Oil & Gas E&P
# 262 | Devon Energy Corporation                       | DVN    | 0.07       | 48.17    | 0.39   | (0.83%)  | Oil & Gas E&P
# 203 | Occidental Petroleum Corporation               | OXY    | 0.09       | 62.33    | -0.03  | (-0.05%) | Oil & Gas E&P
# 120 | Eog Resources, Inc.                            | EOG    | 0.16       | 126.75   | 0.09   | (0.08%)  | Oil & Gas E&P
# 66  | Conocophillips                                 | COP    | 0.29       | 114.89   | 0.77   | (0.67%)  | Oil & Gas E&P
# 229 | Diamondback Energy, Inc.                       | FANG   | 0.08       | 206.97   | 2.06   | (1.01%)  | Oil & Gas E&P
# 391 | Marathon Oil Corporation                       | MRO    | 0.03       | 28.98    | 0.40   | (1.40%)  | Oil & Gas E&P
# 388 | Eqt Corp                                       | EQT    | 0.04       | 37.00    | 0.04   | (0.11%)  | Oil & Gas E&P
# 338 | Coterra Energy Inc.                            | CTRA   | 0.04       | 26.75    | -0.03  | (-0.11%) | Oil & Gas E&P
# 242 | Baker Hughes Company                           | BKR    | 0.08       | 34.32    | -0.37  | (-1.07%) | Oil & Gas Equipment & Services
# 268 | Halliburton Company                            | HAL    | 0.07       | 33.75    | 0.13   | (0.37%)  | Oil & Gas Equipment & Services
# 133 | Schlumberger Limited                           | SLB    | 0.14       | 47.35    | 0.66   | (1.40%)  | Oil & Gas Equipment & Services
# 13  | Exxon Mobil Corporation                        | XOM    | 1.11       | 114.81   | 0.63   | (0.55%)  | Oil & Gas Integrated
# 26  | Chevron Corporation                            | CVX    | 0.58       | 156.74   | -0.01  | (-0.01%) | Oil & Gas Integrated
# 168 | Williams Companies Inc.                        | WMB    | 0.11       | 42.74    | 0.44   | (1.04%)  | Oil & Gas Midstream
# 178 | Oneok, Inc.                                    | OKE    | 0.1        | 82.83    | 0.50   | (0.61%)  | Oil & Gas Midstream
# 277 | Targa Resources Corp.                          | TRGP   | 0.06       | 132.72   | 1.72   | (1.31%)  | Oil & Gas Midstream
# 217 | Kinder Morgan, Inc.                            | KMI    | 0.08       | 19.85    | 0.13   | (0.66%)  | Oil & Gas Midstream
# 154 | Phillips 66                                    | PSX    | 0.13       | 140.50   | 0.03   | (0.02%)  | Oil & Gas Refining & Marketing
# 149 | Marathon Petroleum Corporation                 | MPC    | 0.13       | 175.05   | 0.91   | (0.52%)  | Oil & Gas Refining & Marketing
# 167 | Valero Energy Corporation                      | VLO    | 0.11       | 158.75   | 0.79   | (0.50%)  | Oil & Gas Refining & Marketing
# 470 | Hormel Foods Corporation                       | HRL    | 0.02       | 30.31    | -0.25  | (-0.80%) | Packaged Foods
# 438 | Lamb Weston Holdings, Inc.                     | LW     | 0.03       | 83.70    | 0.96   | (1.16%)  | Packaged Foods
# 419 | Conagra Brands, Inc.                           | CAG    | 0.03       | 28.14    | -0.19  | (-0.69%) | Packaged Foods
# 469 | Campbell Soup Company                          | CPB    | 0.02       | 45.02    | -0.52  | (-1.13%) | Packaged Foods
# 362 | Mccormick & Company, Incorporated Non-Vtg Cs   | MKC    | 0.04       | 69.51    | -0.73  | (-1.05%) | Packaged Foods
# 446 | The J.M. Smucker Company                       | SJM    | 0.02       | 110.38   | -0.27  | (-0.24%) | Packaged Foods
# 236 | General Mills, Inc.                            | GIS    | 0.08       | 62.96    | -0.21  | (-0.33%) | Packaged Foods
# 296 | The Kraft Heinz Company                        | KHC    | 0.06       | 32.12    | 0.12   | (0.39%)  | Packaged Foods
# 405 | Kellanova                                      | K      | 0.03       | 56.65    | -0.05  | (-0.09%) | Packaged Foods
# 404 | International Paper Co.                        | IP     | 0.03       | 43.51    | 0.01   | (0.02%)  | Packaging & Containers
# 353 | Ball Corporation                               | BALL   | 0.04       | 60.03    | 0.32   | (0.53%)  | Packaging & Containers
# 410 | Amcor Plcs                                     | AMCR   | 0.03       | 9.68     | 0.10   | (0.99%)  | Packaging & Containers
# 396 | Packaging Corp of America                      | PKG    | 0.03       | 179.53   | 2.02   | (1.14%)  | Packaging & Containers
# 432 | Westrock Company                               | WRK    | 0.03       | 51.10    | 2.31   | (4.73%)  | Packaging & Containers
# 368 | Avery Dennison Corp.                           | AVY    | 0.04       | 216.46   | 1.34   | (0.62%)  | Packaging & Containers
# 412 | Rollins, Inc.                                  | ROL    | 0.03       | 50.43    | 1.28   | (2.60%)  | Personal Services
# 478 | Walgreens Boots Alliance, Inc                  | WBA    | 0.02       | 11.12    | -0.45  | (-3.89%) | Pharmaceutical Retailers
# 333 | Veralto Corporation                            | VLTO   | 0.04       | 95.30    | 0.95   | (1.00%)  | Pollution & Treatment Controls
# 279 | Vici Properties Inc.                           | VICI   | 0.06       | 27.99    | 0.21   | (0.77%)  | REIT - Diversified
# 331 | Ventas, Inc.                                   | VTR    | 0.04       | 51.83    | 0.04   | (0.08%)  | REIT - Healthcare Facilities
# 142 | Welltower Inc.                                 | WELL   | 0.14       | 105.46   | -0.52  | (-0.49%) | REIT - Healthcare Facilities
# 411 | Healthpeak Properties, Inc.                    | DOC    | 0.03       | 19.49    | -0.04  | (-0.20%) | REIT - Healthcare Facilities
# 430 | Host Hotels & Resorts, Inc.                    | HST    | 0.03       | 17.67    | 0.02   | (0.11%)  | REIT - Hotel & Motel
# 189 | Public Storage                                 | PSA    | 0.1        | 288.83   | 3.44   | (1.21%)  | REIT - Industrial
# 256 | Extra Space Storage, Inc.                      | EXR    | 0.07       | 154.14   | 0.41   | (0.27%)  | REIT - Industrial
# ...
# | Packaged Foods                           |                     9 | GIS, KHC, MKC, K, CAG, LW, SJM, CPB, HRL                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Packaging & Containers                   |                     6 | BALL, AVY, PKG, IP, AMCR, WRK                                                                                |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Personal Services                        |                     1 | ROL                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Pharmaceutical Retailers                 |                     1 | WBA                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Pollution & Treatment Controls           |                     1 | VLTO                                                                                                         |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Diversified                       |                     1 | VICI                                                                                                         |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Healthcare Facilities             |                     3 | WELL, VTR, DOC                                                                                               |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Hotel & Motel                     |                     1 | HST                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Industrial                        |                     3 | PLD, PSA, EXR                                                                                                |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Office                            |                     2 | ARE, BXP                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Residential                       |                     7 | AVB, EQR, INVH, ESS, MAA, UDR, CPT                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Retail                            |                     5 | SPG, O, KIM, REG, FRT                                                                                        |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | REIT - Specialty                         |                     7 | AMT, EQIX, DLR, CCI, IRM, SBAC, WY                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Railroads                                |                     4 | UNP, CSX, NSC, WAB                                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Real Estate Services                     |                     2 | CSGP, CBRE                                                                                                   |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Rental & Leasing Services                |                     1 | URI                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Residential Construction                 |                     4 | DHI, LEN, NVR, PHM                                                                                           |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Resorts & Casinos                        |                     4 | LVS, MGM, WYNN, CZR                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Restaurants                              |                     6 | MCD, SBUX, CMG, YUM, DRI, DPZ                                                                                |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Scientific & Technical Instruments       |                     5 | FTV, GRMN, KEYS, TDY, TRMB                                                                                   |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Security & Protection Services           |                     1 | ALLE                                                                                                         |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Semiconductor Equipment & Materials      |                     4 | AMAT, LRCX, KLAC, TER                                                                                        |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Semiconductors                           |                    14 | NVDA, AVGO, AMD, QCOM, TXN, MU, INTC, ADI, NXPI, MCHP, MPWR, ON, SWKS, QRVO                                  |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Software - Application                   |                    13 | CRM, INTU, NOW, UBER, CDNS, ROP, ADSK, FICO, ANSS, PTC, TYL, DAY, PAYC                                       |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Software - Infrastructure                |                    13 | MSFT, ADBE, ORCL, PANW, SNPS, CRWD, FTNT, GDDY, CPAY, VRSN, GEN, AKAM, FFIV                                  |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Solar                                    |                     2 | FSLR, ENPH                                                                                                   |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Specialty Business Services              |                     3 | CTAS, CPRT, GPN                                                                                              |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Specialty Chemicals                      |                    10 | LIN, SHW, ECL, APD, DD, PPG, IFF, LYB, ALB, EMN                                                              |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Specialty Industrial Machinery           |                    16 | ETN, PH, ITW, EMR, OTIS, AME, IR, CMI, XYL, ROK, DOV, IEX, NDSN, PNR, AOS, GNRC                              |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Specialty Retail                         |                     6 | ORLY, AZO, TSCO, ULTA, BBY, BBWI                                                                             |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Staffing & Employment Services           |                     2 | ADP, PAYX                                                                                                    |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Steel                                    |                     2 | NUE, STLD                                                                                                    |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Telecom Services                         |                     5 | VZ, CMCSA, T, TMUS, CHTR                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Tobacco                                  |                     2 | PM, MO                                                                                                       |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Tools & Accessories                      |                     2 | SNA, SWK                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Travel Services                          |                     6 | BKNG, ABNB, RCL, CCL, EXPE, NCLH                                                                             |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Trucking                                 |                     1 | ODFL                                                                                                         |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Utilities - Diversified                  |                     2 | SRE, AES                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Utilities - Independent Power Producers  |                     2 | VST, NRG                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Utilities - Regulated Electric           |                    23 | NEE, SO, DUK, AEP, D, PEG, PCG, EXC, ED, XEL, EIX, WEC, DTE, ETR, PPL, FE, ES, CNP, AEE, CMS, LNT, EVRG, PNW |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Utilities - Regulated Gas                |                     2 | ATO, NI                                                                                                      |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Utilities - Regulated Water              |                     1 | AWK                                                                                                          |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Utilities - Renewable                    |                     2 | CEG, GEV                                                                                                     |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+
# | Waste Management                         |                     2 | WM, RSG                                                                                                      |
# +------------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ## Calculate performance

# %%
def calculate_performance(symbol, start_date, end_date):
    stock = yf.Ticker(symbol)
    hist = stock.history(start=start_date, end=end_date)
    
    if len(hist) == 0:
        return None
    
    start_price = hist['Close'].iloc[0]
    end_price = hist['Close'].iloc[-1]
    performance = (end_price - start_price) / start_price
    return performance

def get_performance_data(symbol, company, industry, start_date, end_date):
    try:
        performance = calculate_performance(symbol, start_date, end_date)
        if performance is not None:
            return (symbol, company, performance, industry)
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")
    return (symbol, company, None, industry)  # Ensure it returns a tuple with four elements

def fetch_all_performance_data(df, start_date, end_date):
    performance_data = []
    with ThreadPoolExecutor(max_workers=10) as executor:
        futures = [executor.submit(get_performance_data, row['Symbol'], row['Company'], row['Industry'], start_date, end_date) for index, row in df.iterrows()]
        for future in as_completed(futures):
            result = future.result()
            if result and result[2] is not None:  # Check if performance is not None
                performance_data.append(result)
    
    performance_data.sort(key=lambda x: x[2], reverse=True)
    return performance_data

def display_top_bottom_stocks(df, period, top_n, bottom_n, start_date=None, end_date=None):
    if not end_date:
        end_date = datetime.now()
    
    if start_date and end_date:
        start_date = datetime.strptime(start_date, "%Y-%m-%d")
        end_date = datetime.strptime(end_date, "%Y-%m-%d")
    else:
        if period == 'ytd':
            start_date = datetime(end_date.year, 1, 1)
        else:
            delta = {
                '1d': 1,
                '5d': 5,
                '1m': 30,
                '6m': 182,
                '1y': 365,
                '2y': 365*2,
                '3y': 365*3,
                '5y': 365*5,
                '10y': 365*10,
                '20y': 365*20
            }[period]
            start_date = end_date - timedelta(days=delta)
    print("Start and end dates:", start_date, end_date)
    
    performance_data = fetch_all_performance_data(df, start_date, end_date)
    
    print(f"Top {top_n} Stocks:")
    top_industries = []
    for symbol, company, performance, industry in performance_data[:top_n]:
        print(f"{symbol} ({company} - {industry}): {performance*100:.1f}%")
        top_industries.append(industry)
    
    print(f"\nBottom {bottom_n} Stocks:")
    bottom_industries = []
    for symbol, company, performance, industry in performance_data[-bottom_n:]:
        print(f"{symbol} ({company} - {industry}): {performance*100:.1f}%")
        bottom_industries.append(industry)
    
    top_industry_count = Counter(top_industries)
    bottom_industry_count = Counter(bottom_industries)
    
    print(f"\nTop {top_n} Stocks by Industry:")
    for industry, count in top_industry_count.items():
        print(f"{industry}: {count} companies")
    
    print(f"\nBottom {bottom_n} Stocks by Industry:")
    for industry, count in bottom_industry_count.items():
        print(f"{industry}: {count} companies")

# %% [markdown]
# ### QQQ Performance

# %%
# Example usage:
# Parameters
index = 'QQQ'  # Change to 'QQQ' for Nasdaq-100, 'DOW' for Dow Jones, 'IWM' for Russell 2000
df = df_qqq
period = '1y'  # Options: 'ytd', '1d', '5d', '1m', '6m', '1y', '2y', '3y', '5y', '10y', '20y'
top_n = 20
bottom_n = 20
start_date = '1999-01-01'  # Example: '2004-01-01'
end_date = '1999-12-31'  # Example: '2024-12-31'


# Display top and bottom performing stocks
display_top_bottom_stocks(df, period, top_n, bottom_n, start_date, end_date)
# Out:
# Start and end dates: 1999-01-01 00:00:00 1999-12-31 00:00:00
# TSLA: Data doesn't exist for startDate = 915166800, endDate = 946616400
# META: Data doesn't exist for startDate = 915166800, endDate = 946616400
# GOOG: Data doesn't exist for startDate = 915166800, endDate = 946616400
# NFLX: Data doesn't exist for startDate = 915166800, endDate = 946616400
# GOOGL: Data doesn't exist for startDate = 915166800, endDate = 946616400
# AVGO: Data doesn't exist for startDate = 915166800, endDate = 946616400
# TMUS: Data doesn't exist for startDate = 915166800, endDate = 946616400
# ISRG: Data doesn't exist for startDate = 915166800, endDate = 946616400
# PDD: Data doesn't exist for startDate = 915166800, endDate = 946616400
# PANW: Data doesn't exist for startDate = 915166800, endDate = 946616400
# CRWD: Data doesn't exist for startDate = 915166800, endDate = 946616400
# MDLZ: Data doesn't exist for startDate = 915166800, endDate = 946616400
# MELI: Data doesn't exist for startDate = 915166800, endDate = 946616400
# NXPI: Data doesn't exist for startDate = 915166800, endDate = 946616400
# MRVL: Data doesn't exist for startDate = 915166800, endDate = 946616400
# PYPL: Data doesn't exist for startDate = 915166800, endDate = 946616400
# ABNB: Data doesn't exist for startDate = 915166800, endDate = 946616400
# CEG: Data doesn't exist for startDate = 915166800, endDate = 946616400
# WDAY: Data doesn't exist for startDate = 915166800, endDate = 946616400
# CHTR: Data doesn't exist for startDate = 915166800, endDate = 946616400
# KDP: Data doesn't exist for startDate = 915166800, endDate = 946616400
# MRNA: Data doesn't exist for startDate = 915166800, endDate = 946616400
# TTD: Data doesn't exist for startDate = 915166800, endDate = 946616400
# FTNT: Data doesn't exist for startDate = 915166800, endDate = 946616400
# DXCM: Data doesn't exist for startDate = 915166800, endDate = 946616400
# DDOG: Data doesn't exist for startDate = 915166800, endDate = 946616400
# DASH: Data doesn't exist for startDate = 915166800, endDate = 946616400
# KHC: Data doesn't exist for startDate = 915166800, endDate = 946616400
# VRSK: Data doesn't exist for startDate = 915166800, endDate = 946616400
# FANG: Data doesn't exist for startDate = 915166800, endDate = 946616400
# LULU: Data doesn't exist for startDate = 915166800, endDate = 946616400
# GEHC: Data doesn't exist for startDate = 915166800, endDate = 946616400
# ZS: Data doesn't exist for startDate = 915166800, endDate = 946616400
# GFS: Data doesn't exist for startDate = 915166800, endDate = 946616400
# CDW: Data doesn't exist for startDate = 915166800, endDate = 946616400
# ON: Data doesn't exist for startDate = 915166800, endDate = 946616400
# TEAM: Data doesn't exist for startDate = 915166800, endDate = 946616400
# GRAL: Data doesn't exist for startDate = 915166800, endDate = 946616400
# ILMN: Data doesn't exist for startDate = 915166800, endDate = 946616400
# MDB: Data doesn't exist for startDate = 915166800, endDate = 946616400
# ARM: Data doesn't exist for startDate = 915166800, endDate = 946616400
# WBD: Data doesn't exist for startDate = 915166800, endDate = 946616400
# Top 20 Stocks:
# QCOM (QUALCOMM Inc - Semiconductors): 2234.2%
# LRCX (Lam Research Corp - Semiconductor Equipment & Materials): 441.4%
# BIIB (Biogen Inc - Drug Manufacturers - General): 302.0%
# CTSH (Cognizant Technology Solutions Corp - Information Technology Services): 277.1%
# ASML (ASML Holding NV - Semiconductor Equipment & Materials): 233.6%
# ADI (Analog Devices Inc - Semiconductors): 200.2%
# AMAT (Applied Materials Inc - Semiconductor Equipment & Materials): 180.7%
# CPRT (Copart Inc - Specialty Business Services): 179.4%
# ADBE (Adobe Inc - Software - Infrastructure): 164.9%
# INTU (Intuit Inc - Software - Application): 144.6%
# AAPL (Apple Inc - Consumer Electronics): 143.2%
# AMGN (Amgen Inc - Drug Manufacturers - General): 141.7%
# CSGP (CoStar Group Inc - Real Estate Services): 140.6%
# KLAC (KLA Corp - Semiconductor Equipment & Materials): 137.6%
# NVDA (NVIDIA Corp - Semiconductors): 135.6%
# TXN (Texas Instruments Inc - Semiconductors): 128.8%
# CSCO (Cisco Systems Inc - Communication Equipment): 122.8%
# ROP (Roper Technologies Inc - Software - Application): 90.7%
# MCHP (Microchip Technology Inc - Semiconductors): 80.4%
# MSFT (Microsoft Corp - Software - Infrastructure): 66.8%
#
# Bottom 20 Stocks:
# WBA (Walgreens Boots Alliance Inc - Pharmaceutical Retailers): 1.8%
# AMD (Advanced Micro Devices Inc - Semiconductors): 1.6%
# FAST (Fastenal Co - Industrial Distribution): -0.7%
# ODFL (Old Dominion Freight Line Inc - Trucking): -2.2%
# ROST (Ross Stores Inc - Apparel Retail): -5.6%
# AZN (AstraZeneca PLC ADR - Drug Manufacturers - General): -8.4%
# SBUX (Starbucks Corp - Restaurants): -10.4%
# ORLY (O'Reilly Automotive Inc - Specialty Retail): -11.4%
# PEP (PepsiCo Inc - Beverages - Non-Alcoholic): -11.4%
# EXC (Exelon Corp - Utilities - Regulated Electric): -13.2%
# MNST (Monster Beverage Corp - Beverages - Non-Alcoholic): -20.0%
# CTAS (Cintas Corp - Specialty Business Services): -21.4%
# CSX (CSX Corp - Railroads): -22.9%
# XEL (Xcel Energy Inc - Utilities - Regulated Electric): -23.8%
# CDNS (Cadence Design Systems Inc - Software - Application): -24.1%
# AEP (American Electric Power Co Inc - Utilities - Regulated Electric): -27.3%
# ADSK (Autodesk Inc - Software - Application): -27.9%
# CCEP (Coca-Cola Europacific Partners PLC - Beverages - Non-Alcoholic): -40.8%
# IDXX (IDEXX Laboratories Inc - Diagnostics & Research): -41.8%
# BKNG (Booking Holdings Inc - Travel Services): -43.6%
#
# Top 20 Stocks by Industry:
# Semiconductors: 5 companies
# Semiconductor Equipment & Materials: 4 companies
# Drug Manufacturers - General: 2 companies
# Information Technology Services: 1 companies
# Specialty Business Services: 1 companies
# Software - Infrastructure: 2 companies
# Software - Application: 2 companies
# Consumer Electronics: 1 companies
# Real Estate Services: 1 companies
# Communication Equipment: 1 companies
#
# Bottom 20 Stocks by Industry:
# Pharmaceutical Retailers: 1 companies
# Semiconductors: 1 companies
# Industrial Distribution: 1 companies
# Trucking: 1 companies
# Apparel Retail: 1 companies
# Drug Manufacturers - General: 1 companies
# Restaurants: 1 companies
# Specialty Retail: 1 companies
# Beverages - Non-Alcoholic: 3 companies
# Utilities - Regulated Electric: 3 companies
# Specialty Business Services: 1 companies
# Railroads: 1 companies
# Software - Application: 2 companies
# Diagnostics & Research: 1 companies
# Travel Services: 1 companies

# %% [markdown]
# ### SPX Performance

# %%
# Example usage:
# Parameters
index = 'SPX'  # Change to 'QQQ' for Nasdaq-100, 'DOW' for Dow Jones, 'IWM' for Russell 2000
df = df_spx
period = '2y'  # Options: 'ytd', '1d', '5d', '1m', '6m', '1y', '2y', '3y', '5y', '10y', '20y'
top_n = 30
bottom_n = 30
start_date = '2019-01-01'  # Example: '2004-01-01'
end_date = '2019-12-31'  # Example: '2024-12-31'

# Display top and bottom performing stocks
display_top_bottom_stocks(df, period, top_n, bottom_n, start_date, end_date)
# Out:
# Start and end dates: 2019-01-01 00:00:00 2019-12-31 00:00:00
# $BRK.B: possibly delisted; No timezone found
# ABNB: Data doesn't exist for startDate = 1546318800, endDate = 1577768400
# CEG: Data doesn't exist for startDate = 1546318800, endDate = 1577768400
# CARR: Data doesn't exist for startDate = 1546318800, endDate = 1577768400
# GEV: Data doesn't exist for startDate = 1546318800, endDate = 1577768400
# OTIS: Data doesn't exist for startDate = 1546318800, endDate = 1577768400
# KVUE: Data doesn't exist for startDate = 1546318800, endDate = 1577768400
# GEHC: Data doesn't exist for startDate = 1546318800, endDate = 1577768400
# $MTD: possibly delisted; No price data found  (1d 2019-01-01 00:00:00 -> 2019-12-31 00:00:00)
# $MTD: possibly delisted; No price data found  (1d 2019-01-01 00:00:00 -> 2019-12-31 00:00:00)
# VLTO: Data doesn't exist for startDate = 1546318800, endDate = 1577768400
# $BF.B: possibly delisted; No price data found  (1d 2019-01-01 00:00:00 -> 2019-12-31 00:00:00)
# $BF.B: possibly delisted; No price data found  (1d 2019-01-01 00:00:00 -> 2019-12-31 00:00:00)
# SOLV: Data doesn't exist for startDate = 1546318800, endDate = 1577768400
# Top 30 Stocks:
# ENPH (Enphase Energy, Inc. - Solar): 415.7%
# AMD (Advanced Micro Devices - Semiconductors): 141.7%
# PODD (Insulet Corporation - Medical Devices): 130.6%
# BLDR (Builders Firstsource, Inc. - Building Products & Equipment): 120.9%
# PAYC (Paycom Software, Inc. - Software - Application): 119.2%
# TER (Teradyne, Inc. - Semiconductor Equipment & Materials): 118.3%
# LRCX (Lam Research Corp - Semiconductor Equipment & Materials): 116.1%
# FICO (Fair Isaac Corporation - Software - Application): 101.9%
# DAY (Dayforce, Inc. - Software - Application): 101.5%
# KLAC (Kla Corporation - Semiconductor Equipment & Materials): 101.0%
# TGT (Target Corporation - Discount Stores): 100.2%
# GNRC (Generac Holdings Inc - Specialty Industrial Machinery): 98.3%
# MTCH (Match Group, Inc - Internet Content & Information): 95.8%
# BX (Blackstone Inc. - Asset Management): 94.8%
# LDOS (Leidos Holdings, Inc. - Information Technology Services): 91.6%
# CPRT (Copart Inc - Specialty Business Services): 90.6%
# QRVO (Qorvo, Inc. - Semiconductors): 89.9%
# CMG (Chipotle Mexican Grill, Inc. - Restaurants): 88.6%
# DXCM (Dexcom, Inc. - Medical Devices): 87.7%
# AAPL (Apple Inc. - Consumer Electronics): 87.4%
# LULU (Lululemon Athletica Inc. - Apparel Retail): 87.1%
# AMAT (Applied Materials Inc - Semiconductor Equipment & Materials): 85.3%
# TDG (Transdigm Group Incorporated - Aerospace & Defense): 85.3%
# EPAM (Epam Systems, Inc. - Information Technology Services): 84.1%
# CTLT (Catalent, Inc. - Drug Manufacturers - Specialty & Generic): 83.2%
# CDW (Cdw Corporation - Information Technology Services): 82.4%
# SWKS (Skyworks Solutions Inc - Semiconductors): 81.8%
# MKTX (Marketaxess Holdings Inc. - Capital Markets): 80.3%
# ANSS (Ansys Inc - Software - Application): 79.6%
# CSGP (Costar Group Inc - Real Estate Services): 78.3%
#
# Bottom 30 Stocks:
# MMM (3m Company - Conglomerates): -4.8%
# ETSY (Etsy, Inc. - Internet Retail): -5.4%
# FOX (Fox Corporation Class B - Entertainment): -5.8%
# SPG (Simon Property Group, Inc. - REIT - Retail): -5.9%
# ALB (Albemarle Corporation - Specialty Chemicals): -6.0%
# JNPR (Juniper Networks Inc - Communication Equipment): -6.1%
# FDX (Fedex Corporation - Integrated Freight & Logistics): -6.5%
# PFE (Pfizer Inc. - Drug Manufacturers - General): -6.7%
# ROL (Rollins, Inc. - Personal Services): -6.9%
# HAL (Halliburton Company - Oil & Gas Equipment & Services): -7.1%
# MRO (Marathon Oil Corporation - Oil & Gas E&P): -7.5%
# EOG (Eog Resources, Inc. - Oil & Gas E&P): -8.0%
# PTC (Ptc, Inc - Software - Application): -8.1%
# PARA (Paramount Global Class B - Entertainment): -8.1%
# BEN (Franklin Resources, Inc. - Asset Management): -10.4%
# WBA (Walgreens Boots Alliance, Inc - Pharmaceutical Retailers): -10.7%
# AAL (American Airlines Group Inc. - Airlines): -11.8%
# FFIV (F5, Inc. - Software - Infrastructure): -13.6%
# CRWD (Crowdstrike Holdings, Inc. Class A - Software - Infrastructure): -13.7%
# DD (Dupont De Nemours, Inc. - Specialty Chemicals): -18.2%
# TPR (Tapestry, Inc. - Luxury Goods): -18.7%
# KHC (The Kraft Heinz Company - Packaged Foods): -22.8%
# CTRA (Coterra Energy Inc. - Oil & Gas E&P): -26.0%
# BBWI (Bath & Body Works, Inc. - Specialty Retail): -27.2%
# MOS (The Mosaic Company - Agricultural Inputs): -27.3%
# UBER (Uber Technologies, Inc. - Software - Application): -28.5%
# OXY (Occidental Petroleum Corporation - Oil & Gas E&P): -29.9%
# VTRS (Viatris Inc. - Drug Manufacturers - Specialty & Generic): -30.4%
# EQT (Eqt Corp - Oil & Gas E&P): -46.1%
# PCG (Pg&e Corporation - Utilities - Regulated Electric): -54.6%
#
# Top 30 Stocks by Industry:
# Solar: 1 companies
# Semiconductors: 3 companies
# Medical Devices: 2 companies
# Building Products & Equipment: 1 companies
# Software - Application: 4 companies
# Semiconductor Equipment & Materials: 4 companies
# Discount Stores: 1 companies
# Specialty Industrial Machinery: 1 companies
# Internet Content & Information: 1 companies
# Asset Management: 1 companies
# Information Technology Services: 3 companies
# Specialty Business Services: 1 companies
# Restaurants: 1 companies
# Consumer Electronics: 1 companies
# Apparel Retail: 1 companies
# Aerospace & Defense: 1 companies
# Drug Manufacturers - Specialty & Generic: 1 companies
# Capital Markets: 1 companies
# Real Estate Services: 1 companies
#
# Bottom 30 Stocks by Industry:
# Conglomerates: 1 companies
# Internet Retail: 1 companies
# Entertainment: 2 companies
# REIT - Retail: 1 companies
# Specialty Chemicals: 2 companies
# Communication Equipment: 1 companies
# Integrated Freight & Logistics: 1 companies
# Drug Manufacturers - General: 1 companies
# Personal Services: 1 companies
# Oil & Gas Equipment & Services: 1 companies
# Oil & Gas E&P: 5 companies
# Software - Application: 2 companies
# Asset Management: 1 companies
# Pharmaceutical Retailers: 1 companies
# Airlines: 1 companies
# Software - Infrastructure: 2 companies
# Luxury Goods: 1 companies
# Packaged Foods: 1 companies
# Specialty Retail: 1 companies
# Agricultural Inputs: 1 companies
# Drug Manufacturers - Specialty & Generic: 1 companies
# Utilities - Regulated Electric: 1 companies
